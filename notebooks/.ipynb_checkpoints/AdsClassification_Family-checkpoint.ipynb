# %%
import gensim
import numpy as np
import pandas as pd
from gensim.models import KeyedVectors
from gensim.models import Word2Vec
from nltk.tokenize import WordPunctTokenizer
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from collections import Counter
import torch
import torch.nn as nn
import torch.nn.functional as F
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score
import tqdm
from copy import deepcopy
from IPython.display import clear_output
import matplotlib.pyplot as plt

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# %%
DATA_PATH = '../data/raw/labeled_texts_fixed.csv'

# %%
df = pd.read_csv(DATA_PATH)

# %% [markdown]
# # Готовый word2vec

# %%
# %%time
ru_emb = KeyedVectors.load_word2vec_format("../models/word2vec_embeddings/cc.ru.300.vec")
# Out:
# CPU times: total: 5min 45s
# Wall time: 6min 19s

# %%
type(ru_emb.index_to_key)
# Out:
# list

# %%
ru_emb.key_to_index
# Out:
# {',': 0,
#  '.': 1,
#  'и': 2,
#  'в': 3,
#  '</s>': 4,
#  ':': 5,
#  ')': 6,
#  '(': 7,
#  'на': 8,
#  '"': 9,
#  'с': 10,
#  'не': 11,
#  '»': 12,
#  'для': 13,
#  '-': 14,
#  '«': 15,
#  '/': 16,
#  'по': 17,
#  '—': 18,
#  'что': 19,
#  'В': 20,
#  '!': 21,
#  'из': 22,
#  'от': 23,
#  'к': 24,
#  'как': 25,
#  '?': 26,
#  'а': 27,
#  '–': 28,
#  'за': 29,
#  ';': 30,
#  'о': 31,
#  'или': 32,
#  'это': 33,
#  '�': 34,
#  '1': 35,
#  '...': 36,
#  '_': 37,
#  "'": 38,
#  'его': 39,
#  'у': 40,
#  'до': 41,
#  '|': 42,
#  '2': 43,
#  'но': 44,
#  'все': 45,
#  'года': 46,
#  '+': 47,
#  'я': 48,
#  'то': 49,
#  '%': 50,
#  'при': 51,
#  'он': 52,
#  'так': 53,
#  'же': 54,
#  'только': 55,
#  '3': 56,
#  'их': 57,
#  'А': 58,
#  'можно': 59,
#  '#': 60,
#  'был': 61,
#  'И': 62,
#  'время': 63,
#  'также': 64,
#  'году': 65,
#  '10': 66,
#  'было': 67,
#  'будет': 68,
#  'может': 69,
#  'вы': 70,
#  '0': 71,
#  'уже': 72,
#  '[': 73,
#  ']': 74,
#  '4': 75,
#  '>': 76,
#  'чтобы': 77,
#  'есть': 78,
#  'На': 79,
#  'если': 80,
#  '5': 81,
#  '…': 82,
#  'г': 83,
#  'которые': 84,
#  'С': 85,
#  'без': 86,
#  'со': 87,
#  'очень': 88,
#  'бы': 89,
#  'мы': 90,
#  'этом': 91,
#  'более': 92,
#  'под': 93,
#  'они': 94,
#  'быть': 95,
#  'России': 96,
#  'во': 97,
#  'Я': 98,
#  'после': 99,
#  'еще': 100,
#  '№': 101,
#  '7': 102,
#  'того': 103,
#  '20': 104,
#  'Но': 105,
#  'том': 106,
#  'лет': 107,
#  '12': 108,
#  'она': 109,
#  'когда': 110,
#  'этого': 111,
#  'ее': 112,
#  'который': 113,
#  '6': 114,
#  '15': 115,
#  'Если': 116,
#  'UTC': 117,
#  'Вы': 118,
#  'Это': 119,
#  '*': 120,
#  'нет': 121,
#  'были': 122,
#  'Как': 123,
#  'области': 124,
#  'работы': 125,
#  'меня': 126,
#  'была': 127,
#  '8': 128,
#  'где': 129,
#  'По': 130,
#  'чем': 131,
#  '\xad': 132,
#  'Для': 133,
#  '11': 134,
#  'является': 135,
#  'даже': 136,
#  'через': 137,
#  '16': 138,
#  'раз': 139,
#  'об': 140,
#  '•': 141,
#  'Все': 142,
#  'Россия': 143,
#  '18': 144,
#  'всех': 145,
#  '14': 146,
#  'мне': 147,
#  'себя': 148,
#  '13': 149,
#  'год': 150,
#  '=': 151,
#  '2017': 152,
#  'просто': 153,
#  'всего': 154,
#  'ли': 155,
#  '17': 156,
#  'день': 157,
#  '30': 158,
#  'Не': 159,
#  'нас': 160,
#  'этот': 161,
#  'ни': 162,
#  'один': 163,
#  'этой': 164,
#  'них': 165,
#  '2013': 166,
#  '19': 167,
#  '9': 168,
#  '2016': 169,
#  'мая': 170,
#  'вам': 171,
#  'могут': 172,
#  '}': 173,
#  '21': 174,
#  'больше': 175,
#  'О': 176,
#  'км': 177,
#  '\\': 178,
#  'человек': 179,
#  'купить': 180,
#  'тем': 181,
#  'жизни': 182,
#  'При': 183,
#  '00': 184,
#  '22': 185,
#  '2014': 186,
#  'между': 187,
#  'У': 188,
#  'нужно': 189,
#  '2015': 190,
#  '2012': 191,
#  'других': 192,
#  '&': 193,
#  'Он': 194,
#  'кто': 195,
#  'Мы': 196,
#  'руб': 197,
#  'компании': 198,
#  '25': 199,
#  '23': 200,
#  'там': 201,
#  'можете': 202,
#  'сайте': 203,
#  'вот': 204,
#  'К': 205,
#  'которых': 206,
#  'вас': 207,
#  'несколько': 208,
#  'города': 209,
#  'которая': 210,
#  '2011': 211,
#  'им': 212,
#  'ты': 213,
#  'себе': 214,
#  'своей': 215,
#  '24': 216,
#  'сейчас': 217,
#  'ему': 218,
#  'случае': 219,
#  '2010': 220,
#  'времени': 221,
#  'будут': 222,
#  'РФ': 223,
#  '100': 224,
#  'всегда': 225,
#  '→': 226,
#  'свою': 227,
#  'м': 228,
#  'него': 229,
#  'США': 230,
#  'фото': 231,
#  'онлайн': 232,
#  'тоже': 233,
#  'детей': 234,
#  'человека': 235,
#  'надо': 236,
#  'её': 237,
#  'Так': 238,
#  'много': 239,
#  'имеет': 240,
#  'место': 241,
#  'см': 242,
#  'здесь': 243,
#  '50': 244,
#  'бесплатно': 245,
#  'мм': 246,
#  '..': 247,
#  'После': 248,
#  'два': 249,
#  'людей': 250,
#  'другие': 251,
#  'видео': 252,
#  'системы': 253,
#  'эти': 254,
#  'всё': 255,
#  'свой': 256,
#  'часть': 257,
#  'которой': 258,
#  'область': 259,
#  'Москва': 260,
#  'свои': 261,
#  'ещё': 262,
#  'минут': 263,
#  'про': 264,
#  '°': 265,
#  'пока': 266,
#  '000': 267,
#  'дней': 268,
#  'части': 269,
#  'нам': 270,
#  'такой': 271,
#  'марта': 272,
#  'именно': 273,
#  'дома': 274,
#  'сделать': 275,
#  '2009': 276,
#  'М': 277,
#  'Что': 278,
#  'http': 279,
#  'апреля': 280,
#  'июня': 281,
#  'своих': 282,
#  '“': 283,
#  'лишь': 284,
#  '26': 285,
#  'деятельности': 286,
#  'против': 287,
#  'организации': 288,
#  'Москве': 289,
#  'Новости': 290,
#  'да': 291,
#  'сайта': 292,
#  'декабря': 293,
#  'качестве': 294,
#  'января': 295,
#  'связи': 296,
#  'игры': 297,
#  'всем': 298,
#  'например': 299,
#  'Вам': 300,
#  '2008': 301,
#  '28': 302,
#  'над': 303,
#  'перед': 304,
#  'of': 305,
#  '27': 306,
#  'вопрос': 307,
#  'своего': 308,
#  'район': 309,
#  'образом': 310,
#  'лучше': 311,
#  'одной': 312,
#  'Украины': 313,
#  'ноября': 314,
#  'октября': 315,
#  'стал': 316,
#  'собой': 317,
#  'возможность': 318,
#  'июля': 319,
#  '40': 320,
#  'сентября': 321,
#  'сайт': 322,
#  'сегодня': 323,
#  'За': 324,
#  'февраля': 325,
#  'этих': 326,
#  'назад': 327,
#  '29': 328,
#  'мира': 329,
#  'августа': 330,
#  'жизнь': 331,
#  '$': 332,
#  'необходимо': 333,
#  'ничего': 334,
#  'около': 335,
#  '”': 336,
#  'Однако': 337,
#  'должны': 338,
#  'которого': 339,
#  'управления': 340,
#  'дня': 341,
#  'цены': 342,
#  'ул': 343,
#  'помощью': 344,
#  'Российской': 345,
#  'двух': 346,
#  'одного': 347,
#  'статьи': 348,
#  'поэтому': 349,
#  'вместе': 350,
#  'стоит': 351,
#  'цена': 352,
#  'стороны': 353,
#  '́': 354,
#  'тут': 355,
#  'развития': 356,
#  'Да': 357,
#  'потому': 358,
#  'Главная': 359,
#  'люди': 360,
#  'Купить': 361,
#  'такие': 362,
#  'хорошо': 363,
#  'The': 364,
#  'информации': 365,
#  'хотя': 366,
#  'территории': 367,
#  'тех': 368,
#  'работу': 369,
#  'весь': 370,
#  'эту': 371,
#  '©': 372,
#  'часов': 373,
#  'чего': 374,
#  'потом': 375,
#  'теперь': 376,
#  'три': 377,
#  'первый': 378,
#  'должен': 379,
#  'количество': 380,
#  'районе': 381,
#  'либо': 382,
#  'рублей': 383,
#  'Федерации': 384,
#  'вообще': 385,
#  'скачать': 386,
#  'числе': 387,
#  'момент': 388,
#  'Александр': 389,
#  '2007': 390,
#  '09': 391,
#  'из-за': 392,
#  'тогда': 393,
#  'найти': 394,
#  'права': 395,
#  'ней': 396,
#  'сразу': 397,
#  'таких': 398,
#  'виде': 399,
#  'менее': 400,
#  'находится': 401,
#  'течение': 402,
#  'каждый': 403,
#  'Вот': 404,
#  'страны': 405,
#  '31': 406,
#  'город': 407,
#  'делать': 408,
#  'другой': 409,
#  'дом': 410,
#  'Она': 411,
#  'среди': 412,
#  'СССР': 413,
#  'Скачать': 414,
#  'группы': 415,
#  'д': 416,
#  'Они': 417,
#  'данных': 418,
#  'истории': 419,
#  'тот': 420,
#  'новый': 421,
#  'почти': 422,
#  '<': 423,
#  'городе': 424,
#  'ООО': 425,
#  'Вас': 426,
#  'вопросы': 427,
#  'такое': 428,
#  'товара': 429,
#  'внимание': 430,
#  'сам': 431,
#  'этим': 432,
#  'дело': 433,
#  'г.': 434,
#  'воды': 435,
#  'войны': 436,
#  'полностью': 437,
#  'которое': 438,
#  'ним': 439,
#  'Категория': 440,
#  'достаточно': 441,
#  'the': 442,
#  'района': 443,
#  'работе': 444,
#  'часто': 445,
#  'N': 446,
#  'использовать': 447,
#  'стали': 448,
#  '@': 449,
#  'Ну': 450,
#  'период': 451,
#  '01': 452,
#  'работа': 453,
#  'средств': 454,
#  'Когда': 455,
#  'Кроме': 456,
#  '08': 457,
#  'образования': 458,
#  'являются': 459,
#  'котором': 460,
#  'новых': 461,
#  'следует': 462,
#  'нравится': 463,
#  'своим': 464,
#  'Также': 465,
#  'новые': 466,
#  'позволяет': 467,
#  'программы': 468,
#  'информацию': 469,
#  '2006': 470,
#  'ведь': 471,
#  'система': 472,
#  'информация': 473,
#  'участие': 474,
#  'смотреть': 475,
#  'книги': 476,
#  'быстро': 477,
#  'конечно': 478,
#  '·': 479,
#  '38': 480,
#  'грн': 481,
#  'отзывы': 482,
#  'ей': 483,
#  'второй': 484,
#  'название': 485,
#  'самых': 486,
#  'работ': 487,
#  'заказ': 488,
#  'начала': 489,
#  'годы': 490,
#  'слова': 491,
#  'Добавить': 492,
#  'тебя': 493,
#  'получить': 494,
#  'решение': 495,
#  'состав': 496,
#  'всей': 497,
#  'мир': 498,
#  'товаров': 499,
#  'производства': 500,
#  'порно': 501,
#  'результате': 502,
#  'затем': 503,
#  'различных': 504,
#  'данные': 505,
#  'составляет': 506,
#  'большой': 507,
#  'материалы': 508,
#  'сказал': 509,
#  'любой': 510,
#  'мире': 511,
#  'места': 512,
#  'те': 513,
#  'деньги': 514,
#  'типа': 515,
#  'месте': 516,
#  '35': 517,
#  'Поэтому': 518,
#  'компания': 519,
#  'право': 520,
#  'новости': 521,
#  'эта': 522,
#  'условиях': 523,
#  'Сергей': 524,
#  'одна': 525,
#  'имени': 526,
#  'века': 527,
#  'нашей': 528,
#  'нашем': 529,
#  'власти': 530,
#  'услуги': 531,
#  'выше': 532,
#  'Об': 533,
#  '07': 534,
#  'однако': 535,
#  'совсем': 536,
#  'тому': 537,
#  'материалов': 538,
#  'две': 539,
#  'что-то': 540,
#  'таким': 541,
#  'безопасности': 542,
#  'наиболее': 543,
#  'средства': 544,
#  'сети': 545,
#  'основе': 546,
#  'Нет': 547,
#  'свое': 548,
#  'наличии': 549,
#  'соответствии': 550,
#  'Владимир': 551,
#  'модели': 552,
#  '60': 553,
#  '~': 554,
#  'Есть': 555,
#  '02': 556,
#  '45': 557,
#  'тысяч': 558,
#  'работает': 559,
#  'кг': 560,
#  'помощи': 561,
#  'Автор': 562,
#  'возможно': 563,
#  'показать': 564,
#  '05': 565,
#  'сказать': 566,
#  'должна': 567,
#  'конце': 568,
#  'цене': 569,
#  'услуг': 570,
#  'серии': 571,
#  'Украине': 572,
#  'Чтобы': 573,
#  '32': 574,
#  'особенно': 575,
#  'вид': 576,
#  'имя': 577,
#  'регистрации': 578,
#  '....': 579,
#  'стала': 580,
#  'Сегодня': 581,
#  'обл': 582,
#  'друг': 583,
#  'Н': 584,
#  'разных': 585,
#  '2000': 586,
#  'товары': 587,
#  'Фото': 588,
#  'ответ': 589,
#  'проблемы': 590,
#  'Его': 591,
#  'имеют': 592,
#  'многие': 593,
#  '03': 594,
#  'Из': 595,
#  'фильм': 596,
#  'почему': 597,
#  'которую': 598,
#  '06': 599,
#  'одним': 600,
#  'населения': 601,
#  'Во': 602,
#  'I': 603,
#  'действия': 604,
#  'использования': 605,
#  'п': 606,
#  '200': 607,
#  'деревня': 608,
#  '500': 609,
#  'оно': 610,
#  'наших': 611,
#  'шт': 612,
#  'решения': 613,
#  'такого': 614,
#  'говорит': 615,
#  '--': 616,
#  'работать': 617,
#  'ребенка': 618,
#  '04': 619,
#  'самом': 620,
#  'язык': 621,
#  'возможности': 622,
#  'and': 623,
#  'Украина': 624,
#  'практически': 625,
#  'отзыв': 626,
#  'счет': 627,
#  'нового': 628,
#  'тебе': 629,
#  'никогда': 630,
#  'своими': 631,
#  'лица': 632,
#  'Доставка': 633,
#  'Тип': 634,
#  'центр': 635,
#  'качества': 636,
#  'этому': 637,
#  'мой': 638,
#  'получил': 639,
#  'Цена': 640,
#  'характеристики': 641,
#  'могу': 642,
#  'далее': 643,
#  'II': 644,
#  'легко': 645,
#  'Москвы': 646,
#  'нашего': 647,
#  '80': 648,
#  'сезон': 649,
#  'Подробнее': 650,
#  'рядом': 651,
#  'многих': 652,
#  '2005': 653,
#  'нее': 654,
#  'немного': 655,
#  'проекта': 656,
#  'стало': 657,
#  'первой': 658,
#  'Здесь': 659,
#  'Спасибо': 660,
#  'продукции': 661,
#  'одно': 662,
#  'рамках': 663,
#  'стоимость': 664,
#  'рождения': 665,
#  'уровень': 666,
#  'Мне': 667,
#  'обязательно': 668,
#  's': 669,
#  'оборудование': 670,
#  '36': 671,
#  'Республики': 672,
#  'цвета': 673,
#  'C': 674,
#  'р': 675,
#  'категории': 676,
#  'Только': 677,
#  'Очень': 678,
#  'знаю': 679,
#  '33': 680,
#  'интернет': 681,
#  'происходит': 682,
#  'серия': 683,
#  'уровня': 684,
#  'какой': 685,
#  'начале': 686,
#  'культуры': 687,
#  'поскольку': 688,
#  'кроме': 689,
#  'ст': 690,
#  'некоторые': 691,
#  'роль': 692,
#  'всю': 693,
#  'месяц': 694,
#  'село': 695,
#  'ч': 696,
#  'труда': 697,
#  'смерти': 698,
#  'должно': 699,
#  'телефон': 700,
#  'действительно': 701,
#  'список': 702,
#  'ранее': 703,
#  'благодаря': 704,
#  'ну': 705,
#  'Windows': 706,
#  '’': 707,
#  'Этот': 708,
#  'стать': 709,
#  '2004': 710,
#  'ниже': 711,
#  'которым': 712,
#  'нельзя': 713,
#  'отношения': 714,
#  'сами': 715,
#  'одном': 716,
#  'снова': 717,
#  'От': 718,
#  'обычно': 719,
#  'месяцев': 720,
#  'первого': 721,
#  'наш': 722,
#  'a': 723,
#  'перенаправление': 724,
#  'сообщения': 725,
#  'самое': 726,
#  'пути': 727,
#  'пор': 728,
#  'защиты': 729,
#  'б': 730,
#  'раза': 731,
#  'магазине': 732,
#  'данным': 733,
#  'описание': 734,
#  'меньше': 735,
#  '34': 736,
#  'самый': 737,
#  'выбор': 738,
#  'составе': 739,
#  'цвет': 740,
#  'значит': 741,
#  'Андрей': 742,
#  '↓': 743,
#  'номер': 744,
#  'размер': 745,
#  'данной': 746,
#  'службы': 747,
#  'самые': 748,
#  'устройства': 749,
#  '55': 750,
#  'деле': 751,
#  'каждого': 752,
#  'магазин': 753,
#  'постоянно': 754,
#  '48': 755,
#  'сколько': 756,
#  'интернет-магазине': 757,
#  'наши': 758,
#  'выбрать': 759,
#  'такая': 760,
#  'писал': 761,
#  'самого': 762,
#  'to': 763,
#  'нем': 764,
#  'прав': 765,
#  'руки': 766,
#  'питания': 767,
#  'изменения': 768,
#  'представляет': 769,
#  'данный': 770,
#  'компанией': 771,
#  'очередь': 772,
#  'лиц': 773,
#  'движения': 774,
#  'посмотреть': 775,
#  'сможете': 776,
#  'совершенно': 777,
#  'Сейчас': 778,
#  'уж': 779,
#  'формы': 780,
#  'условия': 781,
#  'in': 782,
#  'тему': 783,
#  'никто': 784,
#  'дела': 785,
#  'давно': 786,
#  'компаний': 787,
#  'проект': 788,
#  'Просмотров': 789,
#  'модель': 790,
#  'развитие': 791,
#  'процесс': 792,
#  'качество': 793,
#  'создания': 794,
#  'помощь': 795,
#  'адрес': 796,
#  'Каталог': 797,
#  'самым': 798,
#  'точно': 799,
#  'довольно': 800,
#  'Размер': 801,
#  'стране': 802,
#  'настоящее': 803,
#  '42': 804,
#  'двери': 805,
#  'вполне': 806,
#  'степени': 807,
#  'млн': 808,
#  'некоторых': 809,
#  'самой': 810,
#  'мере': 811,
#  'хочу': 812,
#  '2003': 813,
#  'идет': 814,
#  'новой': 815,
#  'срок': 816,
#  'товар': 817,
#  'школы': 818,
#  '37': 819,
#  'П': 820,
#  'становится': 821,
#  'стран': 822,
#  'женщин': 823,
#  'x': 824,
#  'объявления': 825,
#  'слишком': 826,
#  'вариант': 827,
#  'узнать': 828,
#  'стихи': 829,
#  '44': 830,
#  'др': 831,
#  'нескольких': 832,
#  'корзину': 833,
#  'Новый': 834,
#  'книгу': 835,
#  'одну': 836,
#  'данного': 837,
#  'комментарии': 838,
#  'повышения': 839,
#  'проблем': 840,
#  '300': 841,
#  'тыс.': 842,
#  'частности': 843,
#  '{': 844,
#  '70': 845,
#  'вакансии': 846,
#  'теме': 847,
#  'Ваш': 848,
#  'Теперь': 849,
#  'куда': 850,
#  'ситуации': 851,
#  'техника': 852,
#  'иногда': 853,
#  'отношение': 854,
#  'деятельность': 855,
#  'дальше': 856,
#  'словам': 857,
#  'проведения': 858,
#  'памяти': 859,
#  'До': 860,
#  '39': 861,
#  'сильно': 862,
#  'автор': 863,
#  'уровне': 864,
#  'множество': 865,
#  'спасибо': 866,
#  'число': 867,
#  'Можно': 868,
#  'зависимости': 869,
#  'техники': 870,
#  'технологии': 871,
#  'форме': 872,
#  'Г': 873,
#  'ваш': 874,
#  'государства': 875,
#  'месяца': 876,
#  'участников': 877,
#  'Ты': 878,
#  'Киев': 879,
#  'программа': 880,
#  'точки': 881,
#  'воздуха': 882,
#  'Эта': 883,
#  'транспортной': 884,
#  'группа': 885,
#  'машины': 886,
#  'правило': 887,
#  'статье': 888,
#  'Например': 889,
#  'последние': 890,
#  'xD0': 891,
#  '41': 892,
#  'примерно': 893,
#  'пожалуйста': 894,
#  'правильно': 895,
#  'Еще': 896,
#  'языка': 897,
#  'написал': 898,
#  'согласно': 899,
#  'систем': 900,
#  'л': 901,
#  'ходе': 902,
#  '46': 903,
#  'ремонт': 904,
#  'какие': 905,
#  'силы': 906,
#  'рынке': 907,
#  'Алексей': 908,
#  'иметь': 909,
#  '2001': 910,
#  'денег': 911,
#  'версия': 912,
#  'общества': 913,
#  'оборудования': 914,
#  'значение': 915,
#  'хоть': 916,
#  'своем': 917,
#  '43': 918,
#  'ними': 919,
#  'реализации': 920,
#  'состоянии': 921,
#  'другими': 922,
#  'кого': 923,
#  '2002': 924,
#  'Описание': 925,
#  'Код': 926,
#  'центра': 927,
#  'получения': 928,
#  'ряд': 929,
#  'Дата': 930,
#  'заявил': 931,
#  'статья': 932,
#  'кажется': 933,
#  'A': 934,
#  'опыт': 935,
#  'Р': 936,
#  'прямо': 937,
#  'Другие': 938,
#  'улица': 939,
#  'мог': 940,
#  'суд': 941,
#  'исследования': 942,
#  'предложения': 943,
#  'команды': 944,
#  '90': 945,
#  'органов': 946,
#  'центре': 947,
#  'неделю': 948,
#  'станет': 949,
#  '800': 950,
#  'авто': 951,
#  'история': 952,
#  'сфере': 953,
#  'той': 954,
#  'документов': 955,
#  'То': 956,
#  'мало': 957,
#  'тела': 958,
#  'т.д.': 959,
#  'вокруг': 960,
#  'записи': 961,
#  'видов': 962,
#  'отношении': 963,
#  'дети': 964,
#  'другим': 965,
#  'думаю': 966,
#  'семьи': 967,
#  'Сообщение': 968,
#  'целью': 969,
#  'глаза': 970,
#  'линии': 971,
#  'Видео': 972,
#  'конца': 973,
#  'удалось': 974,
#  '52': 975,
#  'первую': 976,
#  'поможет': 977,
#  'доме': 978,
#  'Цвет': 979,
#  'предприятия': 980,
#  'Б': 981,
#  'Русский': 982,
#  'годах': 983,
#  'Европы': 984,
#  'ко': 985,
#  'класс': 986,
#  'Читать': 987,
#  'зрения': 988,
#  'впервые': 989,
#  'равно': 990,
#  'Таким': 991,
#  'Дмитрий': 992,
#  'недели': 993,
#  'фотографии': 994,
#  'материал': 995,
#  'внутри': 996,
#  'силу': 997,
#  'изделия': 998,
#  'целом': 999,
#  ...}

# %% [markdown]
# # Самостоятельное обучение

# %%
texts = list(df['texts'])

# %%
tokenizer = WordPunctTokenizer()

# %%
data_tok = [tokenizer.tokenize(str(text).lower()) for text in texts]

# %%
train_tokens, test_tokens, y_train, y_test = train_test_split(data_tok, df['nationality'], test_size=0.15)

# %%
y_train.mean()
# Out:
# 0.10372931588046432

# %%
y_test.mean()
# Out:
# 0.0979020979020979

# %%
# %%time
model = Word2Vec(train_tokens, 
                 vector_size=300,      # embedding vector size
                 min_count=0,  # consider words that occured at least 5 times
                 window=5).wv  # define context as a 5-word window around the target word
# Out:
# CPU times: total: 24.9 s
# Wall time: 10.1 s

# %%
model

# %%
class Dictionaries():
        
        def __init__(self, tokens):
            self.count_tokens(tokens)

            self.idx_to_word = ['PADDING', 'UNK'] + list(ru_emb.index_to_key)
            self.word_to_idx = {key: i for i, key in enumerate(self.idx_to_word)}
            #self.idx_counter = [self.words_counter[word] for word in self.idx_to_word]
            self.amount_of_words = len(self.idx_to_word)
                
        def count_tokens(self, tokens):
            self.words_counter = Counter()
            self.amount_of_tokens = 0
            for s in tokens:
                self.words_counter.update(s)
                self.amount_of_tokens += len(s)

# %%
data_dicts = Dictionaries(train_tokens)
idx_to_word = data_dicts.idx_to_word
word_to_idx = data_dicts.word_to_idx
pad_idx = 0
unk_idx = 1

# %%
idx_to_word[337284]
# Out:
# 'PAD'

# %%
word_to_idx
# Out:
# {'PADDING': 0,
#  'UNK': 1,
#  ',': 2,
#  '.': 3,
#  'и': 4,
#  'в': 5,
#  '</s>': 6,
#  ':': 7,
#  ')': 8,
#  '(': 9,
#  'на': 10,
#  '"': 11,
#  'с': 12,
#  'не': 13,
#  '»': 14,
#  'для': 15,
#  '-': 16,
#  '«': 17,
#  '/': 18,
#  'по': 19,
#  '—': 20,
#  'что': 21,
#  'В': 22,
#  '!': 23,
#  'из': 24,
#  'от': 25,
#  'к': 26,
#  'как': 27,
#  '?': 28,
#  'а': 29,
#  '–': 30,
#  'за': 31,
#  ';': 32,
#  'о': 33,
#  'или': 34,
#  'это': 35,
#  '�': 36,
#  '1': 37,
#  '...': 38,
#  '_': 39,
#  "'": 40,
#  'его': 41,
#  'у': 42,
#  'до': 43,
#  '|': 44,
#  '2': 45,
#  'но': 46,
#  'все': 47,
#  'года': 48,
#  '+': 49,
#  'я': 50,
#  'то': 51,
#  '%': 52,
#  'при': 53,
#  'он': 54,
#  'так': 55,
#  'же': 56,
#  'только': 57,
#  '3': 58,
#  'их': 59,
#  'А': 60,
#  'можно': 61,
#  '#': 62,
#  'был': 63,
#  'И': 64,
#  'время': 65,
#  'также': 66,
#  'году': 67,
#  '10': 68,
#  'было': 69,
#  'будет': 70,
#  'может': 71,
#  'вы': 72,
#  '0': 73,
#  'уже': 74,
#  '[': 75,
#  ']': 76,
#  '4': 77,
#  '>': 78,
#  'чтобы': 79,
#  'есть': 80,
#  'На': 81,
#  'если': 82,
#  '5': 83,
#  '…': 84,
#  'г': 85,
#  'которые': 86,
#  'С': 87,
#  'без': 88,
#  'со': 89,
#  'очень': 90,
#  'бы': 91,
#  'мы': 92,
#  'этом': 93,
#  'более': 94,
#  'под': 95,
#  'они': 96,
#  'быть': 97,
#  'России': 98,
#  'во': 99,
#  'Я': 100,
#  'после': 101,
#  'еще': 102,
#  '№': 103,
#  '7': 104,
#  'того': 105,
#  '20': 106,
#  'Но': 107,
#  'том': 108,
#  'лет': 109,
#  '12': 110,
#  'она': 111,
#  'когда': 112,
#  'этого': 113,
#  'ее': 114,
#  'который': 115,
#  '6': 116,
#  '15': 117,
#  'Если': 118,
#  'UTC': 119,
#  'Вы': 120,
#  'Это': 121,
#  '*': 122,
#  'нет': 123,
#  'были': 124,
#  'Как': 125,
#  'области': 126,
#  'работы': 127,
#  'меня': 128,
#  'была': 129,
#  '8': 130,
#  'где': 131,
#  'По': 132,
#  'чем': 133,
#  '\xad': 134,
#  'Для': 135,
#  '11': 136,
#  'является': 137,
#  'даже': 138,
#  'через': 139,
#  '16': 140,
#  'раз': 141,
#  'об': 142,
#  '•': 143,
#  'Все': 144,
#  'Россия': 145,
#  '18': 146,
#  'всех': 147,
#  '14': 148,
#  'мне': 149,
#  'себя': 150,
#  '13': 151,
#  'год': 152,
#  '=': 153,
#  '2017': 154,
#  'просто': 155,
#  'всего': 156,
#  'ли': 157,
#  '17': 158,
#  'день': 159,
#  '30': 160,
#  'Не': 161,
#  'нас': 162,
#  'этот': 163,
#  'ни': 164,
#  'один': 165,
#  'этой': 166,
#  'них': 167,
#  '2013': 168,
#  '19': 169,
#  '9': 170,
#  '2016': 171,
#  'мая': 172,
#  'вам': 173,
#  'могут': 174,
#  '}': 175,
#  '21': 176,
#  'больше': 177,
#  'О': 178,
#  'км': 179,
#  '\\': 180,
#  'человек': 181,
#  'купить': 182,
#  'тем': 183,
#  'жизни': 184,
#  'При': 185,
#  '00': 186,
#  '22': 187,
#  '2014': 188,
#  'между': 189,
#  'У': 190,
#  'нужно': 191,
#  '2015': 192,
#  '2012': 193,
#  'других': 194,
#  '&': 195,
#  'Он': 196,
#  'кто': 197,
#  'Мы': 198,
#  'руб': 199,
#  'компании': 200,
#  '25': 201,
#  '23': 202,
#  'там': 203,
#  'можете': 204,
#  'сайте': 205,
#  'вот': 206,
#  'К': 207,
#  'которых': 208,
#  'вас': 209,
#  'несколько': 210,
#  'города': 211,
#  'которая': 212,
#  '2011': 213,
#  'им': 214,
#  'ты': 215,
#  'себе': 216,
#  'своей': 217,
#  '24': 218,
#  'сейчас': 219,
#  'ему': 220,
#  'случае': 221,
#  '2010': 222,
#  'времени': 223,
#  'будут': 224,
#  'РФ': 225,
#  '100': 226,
#  'всегда': 227,
#  '→': 228,
#  'свою': 229,
#  'м': 230,
#  'него': 231,
#  'США': 232,
#  'фото': 233,
#  'онлайн': 234,
#  'тоже': 235,
#  'детей': 236,
#  'человека': 237,
#  'надо': 238,
#  'её': 239,
#  'Так': 240,
#  'много': 241,
#  'имеет': 242,
#  'место': 243,
#  'см': 244,
#  'здесь': 245,
#  '50': 246,
#  'бесплатно': 247,
#  'мм': 248,
#  '..': 249,
#  'После': 250,
#  'два': 251,
#  'людей': 252,
#  'другие': 253,
#  'видео': 254,
#  'системы': 255,
#  'эти': 256,
#  'всё': 257,
#  'свой': 258,
#  'часть': 259,
#  'которой': 260,
#  'область': 261,
#  'Москва': 262,
#  'свои': 263,
#  'ещё': 264,
#  'минут': 265,
#  'про': 266,
#  '°': 267,
#  'пока': 268,
#  '000': 269,
#  'дней': 270,
#  'части': 271,
#  'нам': 272,
#  'такой': 273,
#  'марта': 274,
#  'именно': 275,
#  'дома': 276,
#  'сделать': 277,
#  '2009': 278,
#  'М': 279,
#  'Что': 280,
#  'http': 281,
#  'апреля': 282,
#  'июня': 283,
#  'своих': 284,
#  '“': 285,
#  'лишь': 286,
#  '26': 287,
#  'деятельности': 288,
#  'против': 289,
#  'организации': 290,
#  'Москве': 291,
#  'Новости': 292,
#  'да': 293,
#  'сайта': 294,
#  'декабря': 295,
#  'качестве': 296,
#  'января': 297,
#  'связи': 298,
#  'игры': 299,
#  'всем': 300,
#  'например': 301,
#  'Вам': 302,
#  '2008': 303,
#  '28': 304,
#  'над': 305,
#  'перед': 306,
#  'of': 307,
#  '27': 308,
#  'вопрос': 309,
#  'своего': 310,
#  'район': 311,
#  'образом': 312,
#  'лучше': 313,
#  'одной': 314,
#  'Украины': 315,
#  'ноября': 316,
#  'октября': 317,
#  'стал': 318,
#  'собой': 319,
#  'возможность': 320,
#  'июля': 321,
#  '40': 322,
#  'сентября': 323,
#  'сайт': 324,
#  'сегодня': 325,
#  'За': 326,
#  'февраля': 327,
#  'этих': 328,
#  'назад': 329,
#  '29': 330,
#  'мира': 331,
#  'августа': 332,
#  'жизнь': 333,
#  '$': 334,
#  'необходимо': 335,
#  'ничего': 336,
#  'около': 337,
#  '”': 338,
#  'Однако': 339,
#  'должны': 340,
#  'которого': 341,
#  'управления': 342,
#  'дня': 343,
#  'цены': 344,
#  'ул': 345,
#  'помощью': 346,
#  'Российской': 347,
#  'двух': 348,
#  'одного': 349,
#  'статьи': 350,
#  'поэтому': 351,
#  'вместе': 352,
#  'стоит': 353,
#  'цена': 354,
#  'стороны': 355,
#  '́': 356,
#  'тут': 357,
#  'развития': 358,
#  'Да': 359,
#  'потому': 360,
#  'Главная': 361,
#  'люди': 362,
#  'Купить': 363,
#  'такие': 364,
#  'хорошо': 365,
#  'The': 366,
#  'информации': 367,
#  'хотя': 368,
#  'территории': 369,
#  'тех': 370,
#  'работу': 371,
#  'весь': 372,
#  'эту': 373,
#  '©': 374,
#  'часов': 375,
#  'чего': 376,
#  'потом': 377,
#  'теперь': 378,
#  'три': 379,
#  'первый': 380,
#  'должен': 381,
#  'количество': 382,
#  'районе': 383,
#  'либо': 384,
#  'рублей': 385,
#  'Федерации': 386,
#  'вообще': 387,
#  'скачать': 388,
#  'числе': 389,
#  'момент': 390,
#  'Александр': 391,
#  '2007': 392,
#  '09': 393,
#  'из-за': 394,
#  'тогда': 395,
#  'найти': 396,
#  'права': 397,
#  'ней': 398,
#  'сразу': 399,
#  'таких': 400,
#  'виде': 401,
#  'менее': 402,
#  'находится': 403,
#  'течение': 404,
#  'каждый': 405,
#  'Вот': 406,
#  'страны': 407,
#  '31': 408,
#  'город': 409,
#  'делать': 410,
#  'другой': 411,
#  'дом': 412,
#  'Она': 413,
#  'среди': 414,
#  'СССР': 415,
#  'Скачать': 416,
#  'группы': 417,
#  'д': 418,
#  'Они': 419,
#  'данных': 420,
#  'истории': 421,
#  'тот': 422,
#  'новый': 423,
#  'почти': 424,
#  '<': 425,
#  'городе': 426,
#  'ООО': 427,
#  'Вас': 428,
#  'вопросы': 429,
#  'такое': 430,
#  'товара': 431,
#  'внимание': 432,
#  'сам': 433,
#  'этим': 434,
#  'дело': 435,
#  'г.': 436,
#  'воды': 437,
#  'войны': 438,
#  'полностью': 439,
#  'которое': 440,
#  'ним': 441,
#  'Категория': 442,
#  'достаточно': 443,
#  'the': 444,
#  'района': 445,
#  'работе': 446,
#  'часто': 447,
#  'N': 448,
#  'использовать': 449,
#  'стали': 450,
#  '@': 451,
#  'Ну': 452,
#  'период': 453,
#  '01': 454,
#  'работа': 455,
#  'средств': 456,
#  'Когда': 457,
#  'Кроме': 458,
#  '08': 459,
#  'образования': 460,
#  'являются': 461,
#  'котором': 462,
#  'новых': 463,
#  'следует': 464,
#  'нравится': 465,
#  'своим': 466,
#  'Также': 467,
#  'новые': 468,
#  'позволяет': 469,
#  'программы': 470,
#  'информацию': 471,
#  '2006': 472,
#  'ведь': 473,
#  'система': 474,
#  'информация': 475,
#  'участие': 476,
#  'смотреть': 477,
#  'книги': 478,
#  'быстро': 479,
#  'конечно': 480,
#  '·': 481,
#  '38': 482,
#  'грн': 483,
#  'отзывы': 484,
#  'ей': 485,
#  'второй': 486,
#  'название': 487,
#  'самых': 488,
#  'работ': 489,
#  'заказ': 490,
#  'начала': 491,
#  'годы': 492,
#  'слова': 493,
#  'Добавить': 494,
#  'тебя': 495,
#  'получить': 496,
#  'решение': 497,
#  'состав': 498,
#  'всей': 499,
#  'мир': 500,
#  'товаров': 501,
#  'производства': 502,
#  'порно': 503,
#  'результате': 504,
#  'затем': 505,
#  'различных': 506,
#  'данные': 507,
#  'составляет': 508,
#  'большой': 509,
#  'материалы': 510,
#  'сказал': 511,
#  'любой': 512,
#  'мире': 513,
#  'места': 514,
#  'те': 515,
#  'деньги': 516,
#  'типа': 517,
#  'месте': 518,
#  '35': 519,
#  'Поэтому': 520,
#  'компания': 521,
#  'право': 522,
#  'новости': 523,
#  'эта': 524,
#  'условиях': 525,
#  'Сергей': 526,
#  'одна': 527,
#  'имени': 528,
#  'века': 529,
#  'нашей': 530,
#  'нашем': 531,
#  'власти': 532,
#  'услуги': 533,
#  'выше': 534,
#  'Об': 535,
#  '07': 536,
#  'однако': 537,
#  'совсем': 538,
#  'тому': 539,
#  'материалов': 540,
#  'две': 541,
#  'что-то': 542,
#  'таким': 543,
#  'безопасности': 544,
#  'наиболее': 545,
#  'средства': 546,
#  'сети': 547,
#  'основе': 548,
#  'Нет': 549,
#  'свое': 550,
#  'наличии': 551,
#  'соответствии': 552,
#  'Владимир': 553,
#  'модели': 554,
#  '60': 555,
#  '~': 556,
#  'Есть': 557,
#  '02': 558,
#  '45': 559,
#  'тысяч': 560,
#  'работает': 561,
#  'кг': 562,
#  'помощи': 563,
#  'Автор': 564,
#  'возможно': 565,
#  'показать': 566,
#  '05': 567,
#  'сказать': 568,
#  'должна': 569,
#  'конце': 570,
#  'цене': 571,
#  'услуг': 572,
#  'серии': 573,
#  'Украине': 574,
#  'Чтобы': 575,
#  '32': 576,
#  'особенно': 577,
#  'вид': 578,
#  'имя': 579,
#  'регистрации': 580,
#  '....': 581,
#  'стала': 582,
#  'Сегодня': 583,
#  'обл': 584,
#  'друг': 585,
#  'Н': 586,
#  'разных': 587,
#  '2000': 588,
#  'товары': 589,
#  'Фото': 590,
#  'ответ': 591,
#  'проблемы': 592,
#  'Его': 593,
#  'имеют': 594,
#  'многие': 595,
#  '03': 596,
#  'Из': 597,
#  'фильм': 598,
#  'почему': 599,
#  'которую': 600,
#  '06': 601,
#  'одним': 602,
#  'населения': 603,
#  'Во': 604,
#  'I': 605,
#  'действия': 606,
#  'использования': 607,
#  'п': 608,
#  '200': 609,
#  'деревня': 610,
#  '500': 611,
#  'оно': 612,
#  'наших': 613,
#  'шт': 614,
#  'решения': 615,
#  'такого': 616,
#  'говорит': 617,
#  '--': 618,
#  'работать': 619,
#  'ребенка': 620,
#  '04': 621,
#  'самом': 622,
#  'язык': 623,
#  'возможности': 624,
#  'and': 625,
#  'Украина': 626,
#  'практически': 627,
#  'отзыв': 628,
#  'счет': 629,
#  'нового': 630,
#  'тебе': 631,
#  'никогда': 632,
#  'своими': 633,
#  'лица': 634,
#  'Доставка': 635,
#  'Тип': 636,
#  'центр': 637,
#  'качества': 638,
#  'этому': 639,
#  'мой': 640,
#  'получил': 641,
#  'Цена': 642,
#  'характеристики': 643,
#  'могу': 644,
#  'далее': 645,
#  'II': 646,
#  'легко': 647,
#  'Москвы': 648,
#  'нашего': 649,
#  '80': 650,
#  'сезон': 651,
#  'Подробнее': 652,
#  'рядом': 653,
#  'многих': 654,
#  '2005': 655,
#  'нее': 656,
#  'немного': 657,
#  'проекта': 658,
#  'стало': 659,
#  'первой': 660,
#  'Здесь': 661,
#  'Спасибо': 662,
#  'продукции': 663,
#  'одно': 664,
#  'рамках': 665,
#  'стоимость': 666,
#  'рождения': 667,
#  'уровень': 668,
#  'Мне': 669,
#  'обязательно': 670,
#  's': 671,
#  'оборудование': 672,
#  '36': 673,
#  'Республики': 674,
#  'цвета': 675,
#  'C': 676,
#  'р': 677,
#  'категории': 678,
#  'Только': 679,
#  'Очень': 680,
#  'знаю': 681,
#  '33': 682,
#  'интернет': 683,
#  'происходит': 684,
#  'серия': 685,
#  'уровня': 686,
#  'какой': 687,
#  'начале': 688,
#  'культуры': 689,
#  'поскольку': 690,
#  'кроме': 691,
#  'ст': 692,
#  'некоторые': 693,
#  'роль': 694,
#  'всю': 695,
#  'месяц': 696,
#  'село': 697,
#  'ч': 698,
#  'труда': 699,
#  'смерти': 700,
#  'должно': 701,
#  'телефон': 702,
#  'действительно': 703,
#  'список': 704,
#  'ранее': 705,
#  'благодаря': 706,
#  'ну': 707,
#  'Windows': 708,
#  '’': 709,
#  'Этот': 710,
#  'стать': 711,
#  '2004': 712,
#  'ниже': 713,
#  'которым': 714,
#  'нельзя': 715,
#  'отношения': 716,
#  'сами': 717,
#  'одном': 718,
#  'снова': 719,
#  'От': 720,
#  'обычно': 721,
#  'месяцев': 722,
#  'первого': 723,
#  'наш': 724,
#  'a': 725,
#  'перенаправление': 726,
#  'сообщения': 727,
#  'самое': 728,
#  'пути': 729,
#  'пор': 730,
#  'защиты': 731,
#  'б': 732,
#  'раза': 733,
#  'магазине': 734,
#  'данным': 735,
#  'описание': 736,
#  'меньше': 737,
#  '34': 738,
#  'самый': 739,
#  'выбор': 740,
#  'составе': 741,
#  'цвет': 742,
#  'значит': 743,
#  'Андрей': 744,
#  '↓': 745,
#  'номер': 746,
#  'размер': 747,
#  'данной': 748,
#  'службы': 749,
#  'самые': 750,
#  'устройства': 751,
#  '55': 752,
#  'деле': 753,
#  'каждого': 754,
#  'магазин': 755,
#  'постоянно': 756,
#  '48': 757,
#  'сколько': 758,
#  'интернет-магазине': 759,
#  'наши': 760,
#  'выбрать': 761,
#  'такая': 762,
#  'писал': 763,
#  'самого': 764,
#  'to': 765,
#  'нем': 766,
#  'прав': 767,
#  'руки': 768,
#  'питания': 769,
#  'изменения': 770,
#  'представляет': 771,
#  'данный': 772,
#  'компанией': 773,
#  'очередь': 774,
#  'лиц': 775,
#  'движения': 776,
#  'посмотреть': 777,
#  'сможете': 778,
#  'совершенно': 779,
#  'Сейчас': 780,
#  'уж': 781,
#  'формы': 782,
#  'условия': 783,
#  'in': 784,
#  'тему': 785,
#  'никто': 786,
#  'дела': 787,
#  'давно': 788,
#  'компаний': 789,
#  'проект': 790,
#  'Просмотров': 791,
#  'модель': 792,
#  'развитие': 793,
#  'процесс': 794,
#  'качество': 795,
#  'создания': 796,
#  'помощь': 797,
#  'адрес': 798,
#  'Каталог': 799,
#  'самым': 800,
#  'точно': 801,
#  'довольно': 802,
#  'Размер': 803,
#  'стране': 804,
#  'настоящее': 805,
#  '42': 806,
#  'двери': 807,
#  'вполне': 808,
#  'степени': 809,
#  'млн': 810,
#  'некоторых': 811,
#  'самой': 812,
#  'мере': 813,
#  'хочу': 814,
#  '2003': 815,
#  'идет': 816,
#  'новой': 817,
#  'срок': 818,
#  'товар': 819,
#  'школы': 820,
#  '37': 821,
#  'П': 822,
#  'становится': 823,
#  'стран': 824,
#  'женщин': 825,
#  'x': 826,
#  'объявления': 827,
#  'слишком': 828,
#  'вариант': 829,
#  'узнать': 830,
#  'стихи': 831,
#  '44': 832,
#  'др': 833,
#  'нескольких': 834,
#  'корзину': 835,
#  'Новый': 836,
#  'книгу': 837,
#  'одну': 838,
#  'данного': 839,
#  'комментарии': 840,
#  'повышения': 841,
#  'проблем': 842,
#  '300': 843,
#  'тыс.': 844,
#  'частности': 845,
#  '{': 846,
#  '70': 847,
#  'вакансии': 848,
#  'теме': 849,
#  'Ваш': 850,
#  'Теперь': 851,
#  'куда': 852,
#  'ситуации': 853,
#  'техника': 854,
#  'иногда': 855,
#  'отношение': 856,
#  'деятельность': 857,
#  'дальше': 858,
#  'словам': 859,
#  'проведения': 860,
#  'памяти': 861,
#  'До': 862,
#  '39': 863,
#  'сильно': 864,
#  'автор': 865,
#  'уровне': 866,
#  'множество': 867,
#  'спасибо': 868,
#  'число': 869,
#  'Можно': 870,
#  'зависимости': 871,
#  'техники': 872,
#  'технологии': 873,
#  'форме': 874,
#  'Г': 875,
#  'ваш': 876,
#  'государства': 877,
#  'месяца': 878,
#  'участников': 879,
#  'Ты': 880,
#  'Киев': 881,
#  'программа': 882,
#  'точки': 883,
#  'воздуха': 884,
#  'Эта': 885,
#  'транспортной': 886,
#  'группа': 887,
#  'машины': 888,
#  'правило': 889,
#  'статье': 890,
#  'Например': 891,
#  'последние': 892,
#  'xD0': 893,
#  '41': 894,
#  'примерно': 895,
#  'пожалуйста': 896,
#  'правильно': 897,
#  'Еще': 898,
#  'языка': 899,
#  'написал': 900,
#  'согласно': 901,
#  'систем': 902,
#  'л': 903,
#  'ходе': 904,
#  '46': 905,
#  'ремонт': 906,
#  'какие': 907,
#  'силы': 908,
#  'рынке': 909,
#  'Алексей': 910,
#  'иметь': 911,
#  '2001': 912,
#  'денег': 913,
#  'версия': 914,
#  'общества': 915,
#  'оборудования': 916,
#  'значение': 917,
#  'хоть': 918,
#  'своем': 919,
#  '43': 920,
#  'ними': 921,
#  'реализации': 922,
#  'состоянии': 923,
#  'другими': 924,
#  'кого': 925,
#  '2002': 926,
#  'Описание': 927,
#  'Код': 928,
#  'центра': 929,
#  'получения': 930,
#  'ряд': 931,
#  'Дата': 932,
#  'заявил': 933,
#  'статья': 934,
#  'кажется': 935,
#  'A': 936,
#  'опыт': 937,
#  'Р': 938,
#  'прямо': 939,
#  'Другие': 940,
#  'улица': 941,
#  'мог': 942,
#  'суд': 943,
#  'исследования': 944,
#  'предложения': 945,
#  'команды': 946,
#  '90': 947,
#  'органов': 948,
#  'центре': 949,
#  'неделю': 950,
#  'станет': 951,
#  '800': 952,
#  'авто': 953,
#  'история': 954,
#  'сфере': 955,
#  'той': 956,
#  'документов': 957,
#  'То': 958,
#  'мало': 959,
#  'тела': 960,
#  'т.д.': 961,
#  'вокруг': 962,
#  'записи': 963,
#  'видов': 964,
#  'отношении': 965,
#  'дети': 966,
#  'другим': 967,
#  'думаю': 968,
#  'семьи': 969,
#  'Сообщение': 970,
#  'целью': 971,
#  'глаза': 972,
#  'линии': 973,
#  'Видео': 974,
#  'конца': 975,
#  'удалось': 976,
#  '52': 977,
#  'первую': 978,
#  'поможет': 979,
#  'доме': 980,
#  'Цвет': 981,
#  'предприятия': 982,
#  'Б': 983,
#  'Русский': 984,
#  'годах': 985,
#  'Европы': 986,
#  'ко': 987,
#  'класс': 988,
#  'Читать': 989,
#  'зрения': 990,
#  'впервые': 991,
#  'равно': 992,
#  'Таким': 993,
#  'Дмитрий': 994,
#  'недели': 995,
#  'фотографии': 996,
#  'материал': 997,
#  'внутри': 998,
#  'силу': 999,
#  ...}

# %%
def index_tokens(tokens_string):
    return([word_to_idx.get(token, unk_idx) for token in tokens_string])

def fill_with_pads(tokens, pad_idx=0):
    max_len = 0
    for tokens_string in tokens:
        max_len = max(max_len, len(tokens_string))
    for tokens_string in tokens:
        for i in range(len(tokens_string), max_len):
            tokens_string.append(pad_idx)
    return tokens

def as_matrix(tokens):
    tokens = deepcopy(tokens)
    for j, s in enumerate(tokens):
        tokens[j] = index_tokens(s)
    tokens = torch.tensor(fill_with_pads(tokens, pad_idx=pad_idx), dtype=torch.int)
    return tokens

def batch_generator(tokens, labels, batch_size=16):
    for i in range(0, len(tokens), batch_size):
        batch = tokens[i: i + batch_size]
        batch_labels = torch.tensor(labels.values[i: i + batch_size], dtype=torch.long)
        yield as_matrix(batch), batch_labels

# %%
a = as_matrix(train_tokens[:16])
a.size()
# Out:
# torch.Size([16, 175])

# %%
a
# Out:
# tensor([[ 37649,      2,   4290,  ...,      0,      0,      0],
#         [    58,     16,  15721,  ...,      0,      0,      0],
#         [ 21324,      1,      3,  ...,      0,      0,      0],
#         ...,
#         [ 21324,      1,      3,  ...,      0,      0,      0],
#         [  5653, 145163,      5,  ...,      0,      0,      0],
#         [  2970,      1,   5701,  ...,      0,      0,      0]],
#        dtype=torch.int32)

# %%
data_dicts.amount_of_words
# Out:
# 600002

# %%
vectors = np.zeros((len(idx_to_word), 300))
vectors[0, :] = np.zeros(300)
vectors[1, :] = (np.random.rand(300) - 0.5) / 300
for i in range(2, len(idx_to_word)):
    vectors[i, :] = ru_emb.get_vector(idx_to_word[i])

# %%
class ConvNN(nn.Module):
    def __init__(self):
        super().__init__()
        self.emb = nn.Embedding(data_dicts.amount_of_words, 300)
        self.emb.load_state_dict({'weight': torch.tensor(vectors)})
        self.emb.weight.requires_grad=False
        self.conv = nn.Sequential(
            nn.Conv1d(300, 300, kernel_size=5),
            nn.ReLU(),
            nn.AdaptiveMaxPool1d(output_size=1)
        )
        self.linear = nn.Linear(300, 2)
    def forward(self, batch):
        emb = self.emb(batch)
        conv = self.conv(emb.transpose(1, 2))
        out = self.linear(conv.squeeze())
        return F.softmax(out)

# %%
nnet = ConvNN()
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(nnet.parameters())

# %%
test_tokens_as_matrix = as_matrix(test_tokens)

# %%
EPOCHS = 100
BATCH_SIZE = 16
train_scores = []
train_scores_mean = []
test_scores = []
test_aucs = []

# %%
np.arange(0, 1)
# Out:
# array([0])

# %%
for epoch in tqdm.notebook.tqdm(range(EPOCHS)):
    nnet.train()
    batches = batch_generator(train_tokens, y_train, batch_size=BATCH_SIZE)
    for i, batch in tqdm.notebook.tqdm(enumerate(batches), total=len(train_tokens) // BATCH_SIZE):
        pred = nnet(batch[0])
        loss = criterion(pred, batch[1])
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        if i % 100 == 0:
            nnet.eval()
            train_score = criterion(nnet(batch[0]), batch[1])
            print(train_score.item())
            train_scores.append(train_score.item())
    nnet.eval()
    train_scores_mean.append(sum(train_scores) / len(train_scores))
    train_scores = []
    test_pred_prob = nnet(test_tokens_as_matrix)
    test_score = criterion(test_pred_prob, torch.tensor(y_test.values))
    test_auc = roc_auc_score(y_test, test_pred_prob.detach().numpy()[:, 1])
    test_scores.append(test_score.item())
    test_aucs.append(test_auc.item())
    clear_output(True)
    print(f'epoch {epoch}/{EPOCHS}')
    print('auc', test_auc.item())
    print('score', test_score.item())
    plt.figure(figsize=(5, 15))
    plt.subplot(2, 1, 1)
    plt.grid()
    plt.plot(np.arange(epoch + 1), test_aucs)
    plt.subplot(2, 1, 2)
    plt.grid()
    plt.plot(np.arange(epoch + 1), train_scores_mean)
    plt.plot(np.arange(epoch + 1), test_scores)
    plt.grid()
    plt.show()
# Out:
# epoch 10/100
# auc 0.98469760742628
# score 0.33838436007499695
#   0%|          | 0/476 [00:00<?, ?it/s]
# C:\Users\andre\AppData\Local\Temp\ipykernel_3884\2546190197.py:17: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return F.softmax(out)
# 0.37570399045944214
# 0.37888070940971375
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [31], line 8
#       6 loss = criterion(pred, batch[1])
#       7 optimizer.zero_grad()
# ----> 8 loss.backward()
#       9 optimizer.step()
#      10 if i % 100 == 0:
#
# File ~\PycharmProjects\AdClassificationProject\venv\lib\site-packages\torch\_tensor.py:487, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     477 if has_torch_function_unary(self):
#     478     return handle_torch_function(
#     479         Tensor.backward,
#     480         (self,),
#    (...)
#     485         inputs=inputs,
#     486     )
# --> 487 torch.autograd.backward(
#     488     self, gradient, retain_graph, create_graph, inputs=inputs
#     489 )
#
# File ~\PycharmProjects\AdClassificationProject\venv\lib\site-packages\torch\autograd\__init__.py:197, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     192     retain_graph = create_graph
#     194 # The reason we repeat same the comment below is that
#     195 # some Python versions print out the first line of a multi-line function
#     196 # calls in the traceback and some print out the last line
# --> 197 Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     198     tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     199     allow_unreachable=True, accumulate_grad=True)
#
# KeyboardInterrupt:

# %% [markdown]
# # RNN

# %%
def index_tokens(tokens_string):
    return([word_to_idx.get(token, unk_idx) for token in tokens_string])

def fill_with_pads(tokens, pad_idx=0):
    max_len = 0
    for tokens_string in tokens:
        max_len = max(max_len, len(tokens_string))
    for tokens_string in tokens:
        for i in range(len(tokens_string), max_len):
            tokens_string.append(pad_idx)
    return tokens

def as_matrix(tokens):
    tokens = deepcopy(tokens)
    for j, s in enumerate(tokens):
        tokens[j] = index_tokens(s)
    tokens = torch.tensor(fill_with_pads(tokens, pad_idx=pad_idx), dtype=torch.int)
    return tokens

def batch_generator(tokens, labels, batch_size=16):
    for i in range(0, len(tokens), batch_size):
        batch = tokens[i: i + batch_size]
        #eos_indices = [len(seq) - 1 for seq in batch]
        batch_labels = torch.tensor(labels.values[i: i + batch_size], dtype=torch.long)
        yield as_matrix(batch), batch_labels

# %%
test_tokens_as_matrix = as_matrix(test_tokens)
test_eos_indices = [len(seq) - 1 for seq in test_tokens]

# %%
test_tokens_as_matrix = test_tokens_as_matrix[:500]
test_eos_indices = test_eos_indices[:500]
y_test = y_test[:500]
# Out:
# C:\Users\andre\AppData\Local\Temp\ipykernel_3884\2094621328.py:3: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   y_test = y_test[:500]

# %%
class RecNN(nn.Module):
    def __init__(self):
        super().__init__()
        self.emb = nn.Embedding(data_dicts.amount_of_words, 300)
        self.emb.load_state_dict({'weight': torch.tensor(vectors)})
        self.emb.weight.requires_grad=False
        self.gru = nn.GRU(300, 300, batch_first=True)
        self.linear = nn.Linear(300, 2)
    def forward(self, batch):
        emb = self.emb(batch)
        states, last_states = self.gru(emb)
        #last_states = states[np.arange(len(batch)), eos_indices]
        out = self.linear(last_states.squeeze())
        #print(emb.size(), last_states.size(), out.size())
        return F.softmax(out)

# %%
nnet = RecNN()
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(nnet.parameters())

# %%
EPOCHS = 100
BATCH_SIZE = 16
train_scores = []
train_scores_mean = []
test_scores = []
test_aucs = []

# %%
for epoch in tqdm.notebook.tqdm(range(EPOCHS)):
    nnet.train()
    batches = batch_generator(train_tokens, y_train, batch_size=BATCH_SIZE)
    for i, batch in tqdm.notebook.tqdm(enumerate(batches), total=len(train_tokens) // BATCH_SIZE):
        pred = nnet(batch[0])
        loss = criterion(pred, batch[1])
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        if i % 100 == 0:
            nnet.eval()
            train_score = criterion(nnet(batch[0]), batch[1])
            print(train_score.item())
            train_scores.append(train_score.item())
    nnet.eval()
    train_scores_mean.append(sum(train_scores) / len(train_scores))
    train_scores = []
    test_pred_prob = nnet(test_tokens_as_matrix)
    test_score = criterion(test_pred_prob, torch.tensor(y_test.values))
    test_auc = roc_auc_score(y_test, test_pred_prob.detach().numpy()[:, 1])
    test_scores.append(test_score.item())
    test_aucs.append(test_auc.item())
    clear_output(True)
    print(f'epoch {epoch}/{EPOCHS}')
    print('auc', test_auc.item())
    print('score', test_score.item())
    plt.figure(figsize=(5, 10))
    plt.subplot(2, 1, 1)
    plt.plot(np.arange(epoch + 1), test_aucs)
    plt.grid()
    plt.title('Test ROC AUC')
    plt.xlabel('Num. of epochs')
    plt.ylabel('ROC AUC')
    plt.subplot(2, 1, 2)
    plt.plot(np.arange(epoch + 1), train_scores_mean, label='Train loss')
    plt.plot(np.arange(epoch + 1), test_scores, label='Test loss')
    plt.title('Loss')
    plt.xlabel('Num. of epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid()
    plt.show()
# Out:
# epoch 0/100
# auc 0.49976058226393405
# score 0.40526193380355835
#   0%|          | 0/476 [00:00<?, ?it/s]
# C:\Users\andre\AppData\Local\Temp\ipykernel_3884\60674017.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return F.softmax(out)
# 0.43826183676719666
# 0.5007618069648743
# 0.3132619559764862
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [128], line 5
#       3 batches = batch_generator(train_tokens, y_train, batch_size=BATCH_SIZE)
#       4 for i, batch in tqdm.notebook.tqdm(enumerate(batches), total=len(train_tokens) // BATCH_SIZE):
# ----> 5     pred = nnet(batch[0])
#       6     loss = criterion(pred, batch[1])
#       7     optimizer.zero_grad()
#
# File ~\PycharmProjects\AdClassificationProject\venv\lib\site-packages\torch\nn\modules\module.py:1190, in Module._call_impl(self, *input, **kwargs)
#    1186 # If we don't have any hooks, we want to skip the rest of the logic in
#    1187 # this function, and just call forward.
#    1188 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1189         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1190     return forward_call(*input, **kwargs)
#    1191 # Do not call functions when jit is used
#    1192 full_backward_hooks, non_full_backward_hooks = [], []
#
# Cell In [125], line 11, in RecNN.forward(self, batch)
#       9 def forward(self, batch):
#      10     emb = self.emb(batch)
# ---> 11     states, last_states = self.gru(emb)
#      12     #last_states = states[np.arange(len(batch)), eos_indices]
#      13     out = self.linear(last_states.squeeze())
#
# File ~\PycharmProjects\AdClassificationProject\venv\lib\site-packages\torch\nn\modules\module.py:1190, in Module._call_impl(self, *input, **kwargs)
#    1186 # If we don't have any hooks, we want to skip the rest of the logic in
#    1187 # this function, and just call forward.
#    1188 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1189         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1190     return forward_call(*input, **kwargs)
#    1191 # Do not call functions when jit is used
#    1192 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~\PycharmProjects\AdClassificationProject\venv\lib\site-packages\torch\nn\modules\rnn.py:955, in GRU.forward(self, input, hx)
#     953 self.check_forward_args(input, hx, batch_sizes)
#     954 if batch_sizes is None:
# --> 955     result = _VF.gru(input, hx, self._flat_weights, self.bias, self.num_layers,
#     956                      self.dropout, self.training, self.bidirectional, self.batch_first)
#     957 else:
#     958     result = _VF.gru(input, batch_sizes, hx, self._flat_weights, self.bias,
#     959                      self.num_layers, self.dropout, self.training, self.bidirectional)
#
# KeyboardInterrupt:

# %% [markdown]
# # ООП

# %%
def print_metrics(epoch, test_aucs, train_scores_mean, test_scores):
    clear_output(True)
    print(f'epoch {epoch}/100')
    print('auc', test_aucs[-1])
    print('score', test_scores[-1])
    plt.figure(figsize=(5, 10))
    plt.subplot(2, 1, 1)
    plt.plot(np.arange(epoch + 1), test_aucs)
    plt.grid()
    plt.title('Test ROC AUC')
    plt.xlabel('Num. of epochs')
    plt.ylabel('ROC AUC')
    plt.subplot(2, 1, 2)
    plt.plot(np.arange(epoch + 1), train_scores_mean, label='Train loss')
    plt.plot(np.arange(epoch + 1), test_scores, label='Test loss')
    plt.title('Loss')
    plt.xlabel('Num. of epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid()
    plt.show()

# %%
class ConvNN(nn.Module):
    def __init__(self, vectors, n_of_words):
        dim = vectors.shape[1]
        super().__init__()
        self.emb = nn.Embedding(n_of_words, dim)
        self.emb.load_state_dict({'weight': torch.tensor(vectors)})
        self.emb.weight.requires_grad=False
        self.conv = nn.Sequential(
            nn.Conv1d(dim, dim, kernel_size=5),
            nn.ReLU(),
            nn.AdaptiveMaxPool1d(output_size=1)
        )
        self.linear = nn.Linear(dim, 2)
    def forward(self, batch):
        emb = self.emb(batch)
        conv = self.conv(emb.transpose(1, 2))
        out = self.linear(conv.squeeze())
        return F.softmax(out)

# %%
class Classifier():
    
    def __init__(self, batch_size=16, epochs=100):
        self.batch_size = batch_size
        self.epochs = epochs
    
    def preprocess(self, vectors_file_path):
        self.emb = KeyedVectors.load_word2vec_format(vectors_file_path)
        
        self.pad_idx = 0
        self.unk_idx = 1
        
        self.idx_to_word = ['PADDING', 'UNK'] + list(self.emb.index_to_key)
        self.word_to_idx = {key: i for i, key in enumerate(self.idx_to_word)}
        self.amount_of_words = len(self.idx_to_word)
        
        self.vectors = np.zeros((len(self.idx_to_word), 300))
        self.vectors[0, :] = np.zeros(300)
        self.vectors[1, :] = (np.random.rand(300) - 0.5) / 300
        for i in range(2, len(self.idx_to_word)):
            self.vectors[i, :] = self.emb.get_vector(self.idx_to_word[i])
    
    def fit(self, train_tokens, y_train, test_tokens, y_test, reinitialize=True):
        if reinitialize:
            self.nnet = ConvNN(self.vectors, self.amount_of_words).to(device)
            train_scores = []
            train_scores_mean = []
            test_scores = []
            test_aucs = []
            test_tokens_as_matrix = self.as_matrix(test_tokens)
        criterion = nn.CrossEntropyLoss()
        optimizer = torch.optim.Adam(self.nnet.parameters())
        for epoch in tqdm.notebook.tqdm(range(self.epochs)):
            self.nnet.train()
            batches = self.batch_generator(train_tokens, y_train)
            for i, batch in tqdm.notebook.tqdm(enumerate(batches), total=len(train_tokens) // self.batch_size):
                pred = self.nnet(batch[0])
                loss = criterion(pred, batch[1])
                optimizer.zero_grad()
                loss.backward()
                optimizer.step()
                if i % 100 == 0:
                    self.nnet.eval()
                    train_score = criterion(self.nnet(batch[0]), batch[1])
                    print(train_score.item())
                    train_scores.append(train_score.item())
            self.nnet.eval()
            train_scores_mean.append(sum(train_scores) / len(train_scores))
            train_scores = []
            test_pred_prob = self.nnet(test_tokens_as_matrix)
            test_score = criterion(test_pred_prob, torch.tensor(y_test.values, device=device))
            test_auc = roc_auc_score(y_test, test_pred_prob.detach().numpy()[:, 1])
            test_scores.append(test_score.item())
            test_aucs.append(test_auc.item())
            print_metrics(epoch, test_aucs, train_scores_mean, test_scores)

    def count_tokens(self, tokens):
        self.words_counter = Counter()
        self.amount_of_tokens = 0
        for s in tokens:
            self.words_counter.update(s)
            self.amount_of_tokens += len(s)
    
    def index_tokens(self, tokens_string):
        return([self.word_to_idx.get(token, self.unk_idx) for token in tokens_string])

    def fill_with_pads(self, tokens):
        tokens = deepcopy(tokens)
        max_len = 0
        for tokens_string in tokens:
            max_len = max(max_len, len(tokens_string))
        for tokens_string in tokens:
            for i in range(len(tokens_string), max_len):
                tokens_string.append(self.pad_idx)
        return tokens

    def as_matrix(self, tokens):
        tokens = deepcopy(tokens)
        for j, s in enumerate(tokens):
            tokens[j] = self.index_tokens(s)
        tokens = torch.tensor(self.fill_with_pads(tokens), dtype=torch.int, device=device)
        return tokens

    def batch_generator(self, tokens, labels):
        for i in range(0, len(tokens), self.batch_size):
            batch = tokens[i: i + self.batch_size]
            batch_labels = torch.tensor(labels.values[i: i + self.batch_size], dtype=torch.long, device=device)
            yield self.as_matrix(batch), batch_labels

# %%
clf = Classifier()

# %%
# %%time
clf.preprocess("../models/word2vec_embeddings/cc.ru.300.vec")
# Out:
# CPU times: total: 5min 24s
# Wall time: 6min 10s

# %%
# %%time
clf.fit(train_tokens, y_train, test_tokens, y_test, reinitialize=True)
# Out:
# epoch 5/100
# auc 0.7424003322259135
# score 0.3747328519821167
#   0%|          | 0/506 [00:00<?, ?it/s]
# C:\Users\andre\AppData\Local\Temp\ipykernel_12780\1685657459.py:18: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return F.softmax(out)
# 0.37576308846473694
# 0.3132616877555847
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File <timed eval>:1
#
# Cell In [44], line 37, in Classifier.fit(self, train_tokens, y_train, test_tokens, y_test, reinitialize)
#      35 batches = self.batch_generator(train_tokens, y_train)
#      36 for i, batch in tqdm.notebook.tqdm(enumerate(batches), total=len(train_tokens) // self.batch_size):
# ---> 37     pred = self.nnet(batch[0])
#      38     loss = criterion(pred, batch[1])
#      39     optimizer.zero_grad()
#
# File ~\PycharmProjects\AdClassificationProject\venv\lib\site-packages\torch\nn\modules\module.py:1190, in Module._call_impl(self, *input, **kwargs)
#    1186 # If we don't have any hooks, we want to skip the rest of the logic in
#    1187 # this function, and just call forward.
#    1188 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1189         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1190     return forward_call(*input, **kwargs)
#    1191 # Do not call functions when jit is used
#    1192 full_backward_hooks, non_full_backward_hooks = [], []
#
# Cell In [43], line 16, in ConvNN.forward(self, batch)
#      14 def forward(self, batch):
#      15     emb = self.emb(batch)
# ---> 16     conv = self.conv(emb.transpose(1, 2))
#      17     out = self.linear(conv.squeeze())
#      18     return F.softmax(out)
#
# File ~\PycharmProjects\AdClassificationProject\venv\lib\site-packages\torch\nn\modules\module.py:1190, in Module._call_impl(self, *input, **kwargs)
#    1186 # If we don't have any hooks, we want to skip the rest of the logic in
#    1187 # this function, and just call forward.
#    1188 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1189         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1190     return forward_call(*input, **kwargs)
#    1191 # Do not call functions when jit is used
#    1192 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~\PycharmProjects\AdClassificationProject\venv\lib\site-packages\torch\nn\modules\container.py:204, in Sequential.forward(self, input)
#     202 def forward(self, input):
#     203     for module in self:
# --> 204         input = module(input)
#     205     return input
#
# File ~\PycharmProjects\AdClassificationProject\venv\lib\site-packages\torch\nn\modules\module.py:1190, in Module._call_impl(self, *input, **kwargs)
#    1186 # If we don't have any hooks, we want to skip the rest of the logic in
#    1187 # this function, and just call forward.
#    1188 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1189         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1190     return forward_call(*input, **kwargs)
#    1191 # Do not call functions when jit is used
#    1192 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~\PycharmProjects\AdClassificationProject\venv\lib\site-packages\torch\nn\modules\conv.py:313, in Conv1d.forward(self, input)
#     312 def forward(self, input: Tensor) -> Tensor:
# --> 313     return self._conv_forward(input, self.weight, self.bias)
#
# File ~\PycharmProjects\AdClassificationProject\venv\lib\site-packages\torch\nn\modules\conv.py:309, in Conv1d._conv_forward(self, input, weight, bias)
#     305 if self.padding_mode != 'zeros':
#     306     return F.conv1d(F.pad(input, self._reversed_padding_repeated_twice, mode=self.padding_mode),
#     307                     weight, bias, self.stride,
#     308                     _single(0), self.dilation, self.groups)
# --> 309 return F.conv1d(input, weight, bias, self.stride,
#     310                 self.padding, self.dilation, self.groups)
#
# KeyboardInterrupt:

# %%
clf_1.emb

# %%
1422638400 / 1024 / 1024
# Out:
# 1356.7337036132812

# %%
720002400 / 1024 / 1024
# Out:
# 686.6477966308594
