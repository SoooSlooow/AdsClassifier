# %%
import gensim
import numpy as np
import pandas as pd
from gensim.models import KeyedVectors
from gensim.models import Word2Vec
from nltk.tokenize import WordPunctTokenizer
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from collections import Counter
import torch
import torch.nn as nn
import torch.nn.functional as F
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score
import tqdm
from copy import deepcopy

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# %%
DATA_PATH = '../data/raw/labeled_texts_fixed.csv'

# %%
df = pd.read_csv(DATA_PATH)

# %% [markdown]
# # Готовый word2vec

# %%
# %%time
ru_emb = KeyedVectors.load_word2vec_format("../models/word2vec_embeddings/cc.ru.300.vec")
# Out:
# CPU times: total: 7min 15s
# Wall time: 8min

# %%
ru_emb.most_similar('славяне')
# Out:
# [('Славяне', 0.833034336566925),
#  ('германцы', 0.7025650143623352),
#  ('русичи', 0.702156126499176),
#  ('финно-угры', 0.6992863416671753),
#  ('славян', 0.6982200741767883),
#  ('индоевропейцы', 0.6871833801269531),
#  ('русы', 0.6846401691436768),
#  ('славянские', 0.670945405960083),
#  ('балты', 0.6670456528663635),
#  ('скандинавы', 0.661027729511261)]

# %%
type(ru_emb.index_to_key)
# Out:
# list

# %% [markdown]
# # Самостоятельное обучение

# %%
texts = list(df['texts'])

# %%
tokenizer = WordPunctTokenizer()

# %%
data_tok = [tokenizer.tokenize(str(text).lower()) for text in texts]

# %%
train_tokens, test_tokens, y_train, y_test = train_test_split(data_tok, df['nationality'], test_size=0.2)

# %%
y_train.mean()
# Out:
# 0.10233534505379166

# %%
len(test_tokens)
# Out:
# 1906

# %%
# %%time
model = Word2Vec(train_tokens, 
                 vector_size=300,      # embedding vector size
                 min_count=0,  # consider words that occured at least 5 times
                 window=5).wv  # define context as a 5-word window around the target word
# Out:
# CPU times: total: 16.2 s
# Wall time: 6.2 s

# %%
model

# %%
class Dictionaries():
        
        def __init__(self, tokens):
            self.count_tokens(tokens)

            self.idx_to_word = ['PADDING', 'UNK'] + list(ru_emb.index_to_key)
            self.word_to_idx = {key: i for i, key in enumerate(self.idx_to_word)}
            #self.idx_counter = [self.words_counter[word] for word in self.idx_to_word]
            self.amount_of_words = len(self.idx_to_word)
                
        def count_tokens(self, tokens):
            self.words_counter = Counter()
            self.amount_of_tokens = 0
            for s in tokens:
                self.words_counter.update(s)
                self.amount_of_tokens += len(s)

# %%
data_dicts = Dictionaries(train_tokens)
idx_to_word = data_dicts.idx_to_word
word_to_idx = data_dicts.word_to_idx
pad_idx = 0
unk_idx = 1

# %%
idx_to_word[337284]
# Out:
# 'PAD'

# %%
a = [2, 4, 5]
a[2:4]
# Out:
# [5]

# %%
word_to_idx
# Out:
# {'PADDING': 0,
#  'UNK': 1,
#  ',': 2,
#  '.': 3,
#  'и': 4,
#  'в': 5,
#  '</s>': 6,
#  ':': 7,
#  ')': 8,
#  '(': 9,
#  'на': 10,
#  '"': 11,
#  'с': 12,
#  'не': 13,
#  '»': 14,
#  'для': 15,
#  '-': 16,
#  '«': 17,
#  '/': 18,
#  'по': 19,
#  '—': 20,
#  'что': 21,
#  'В': 22,
#  '!': 23,
#  'из': 24,
#  'от': 25,
#  'к': 26,
#  'как': 27,
#  '?': 28,
#  'а': 29,
#  '–': 30,
#  'за': 31,
#  ';': 32,
#  'о': 33,
#  'или': 34,
#  'это': 35,
#  '�': 36,
#  '1': 37,
#  '...': 38,
#  '_': 39,
#  "'": 40,
#  'его': 41,
#  'у': 42,
#  'до': 43,
#  '|': 44,
#  '2': 45,
#  'но': 46,
#  'все': 47,
#  'года': 48,
#  '+': 49,
#  'я': 50,
#  'то': 51,
#  '%': 52,
#  'при': 53,
#  'он': 54,
#  'так': 55,
#  'же': 56,
#  'только': 57,
#  '3': 58,
#  'их': 59,
#  'А': 60,
#  'можно': 61,
#  '#': 62,
#  'был': 63,
#  'И': 64,
#  'время': 65,
#  'также': 66,
#  'году': 67,
#  '10': 68,
#  'было': 69,
#  'будет': 70,
#  'может': 71,
#  'вы': 72,
#  '0': 73,
#  'уже': 74,
#  '[': 75,
#  ']': 76,
#  '4': 77,
#  '>': 78,
#  'чтобы': 79,
#  'есть': 80,
#  'На': 81,
#  'если': 82,
#  '5': 83,
#  '…': 84,
#  'г': 85,
#  'которые': 86,
#  'С': 87,
#  'без': 88,
#  'со': 89,
#  'очень': 90,
#  'бы': 91,
#  'мы': 92,
#  'этом': 93,
#  'более': 94,
#  'под': 95,
#  'они': 96,
#  'быть': 97,
#  'России': 98,
#  'во': 99,
#  'Я': 100,
#  'после': 101,
#  'еще': 102,
#  '№': 103,
#  '7': 104,
#  'того': 105,
#  '20': 106,
#  'Но': 107,
#  'том': 108,
#  'лет': 109,
#  '12': 110,
#  'она': 111,
#  'когда': 112,
#  'этого': 113,
#  'ее': 114,
#  'который': 115,
#  '6': 116,
#  '15': 117,
#  'Если': 118,
#  'UTC': 119,
#  'Вы': 120,
#  'Это': 121,
#  '*': 122,
#  'нет': 123,
#  'были': 124,
#  'Как': 125,
#  'области': 126,
#  'работы': 127,
#  'меня': 128,
#  'была': 129,
#  '8': 130,
#  'где': 131,
#  'По': 132,
#  'чем': 133,
#  '\xad': 134,
#  'Для': 135,
#  '11': 136,
#  'является': 137,
#  'даже': 138,
#  'через': 139,
#  '16': 140,
#  'раз': 141,
#  'об': 142,
#  '•': 143,
#  'Все': 144,
#  'Россия': 145,
#  '18': 146,
#  'всех': 147,
#  '14': 148,
#  'мне': 149,
#  'себя': 150,
#  '13': 151,
#  'год': 152,
#  '=': 153,
#  '2017': 154,
#  'просто': 155,
#  'всего': 156,
#  'ли': 157,
#  '17': 158,
#  'день': 159,
#  '30': 160,
#  'Не': 161,
#  'нас': 162,
#  'этот': 163,
#  'ни': 164,
#  'один': 165,
#  'этой': 166,
#  'них': 167,
#  '2013': 168,
#  '19': 169,
#  '9': 170,
#  '2016': 171,
#  'мая': 172,
#  'вам': 173,
#  'могут': 174,
#  '}': 175,
#  '21': 176,
#  'больше': 177,
#  'О': 178,
#  'км': 179,
#  '\\': 180,
#  'человек': 181,
#  'купить': 182,
#  'тем': 183,
#  'жизни': 184,
#  'При': 185,
#  '00': 186,
#  '22': 187,
#  '2014': 188,
#  'между': 189,
#  'У': 190,
#  'нужно': 191,
#  '2015': 192,
#  '2012': 193,
#  'других': 194,
#  '&': 195,
#  'Он': 196,
#  'кто': 197,
#  'Мы': 198,
#  'руб': 199,
#  'компании': 200,
#  '25': 201,
#  '23': 202,
#  'там': 203,
#  'можете': 204,
#  'сайте': 205,
#  'вот': 206,
#  'К': 207,
#  'которых': 208,
#  'вас': 209,
#  'несколько': 210,
#  'города': 211,
#  'которая': 212,
#  '2011': 213,
#  'им': 214,
#  'ты': 215,
#  'себе': 216,
#  'своей': 217,
#  '24': 218,
#  'сейчас': 219,
#  'ему': 220,
#  'случае': 221,
#  '2010': 222,
#  'времени': 223,
#  'будут': 224,
#  'РФ': 225,
#  '100': 226,
#  'всегда': 227,
#  '→': 228,
#  'свою': 229,
#  'м': 230,
#  'него': 231,
#  'США': 232,
#  'фото': 233,
#  'онлайн': 234,
#  'тоже': 235,
#  'детей': 236,
#  'человека': 237,
#  'надо': 238,
#  'её': 239,
#  'Так': 240,
#  'много': 241,
#  'имеет': 242,
#  'место': 243,
#  'см': 244,
#  'здесь': 245,
#  '50': 246,
#  'бесплатно': 247,
#  'мм': 248,
#  '..': 249,
#  'После': 250,
#  'два': 251,
#  'людей': 252,
#  'другие': 253,
#  'видео': 254,
#  'системы': 255,
#  'эти': 256,
#  'всё': 257,
#  'свой': 258,
#  'часть': 259,
#  'которой': 260,
#  'область': 261,
#  'Москва': 262,
#  'свои': 263,
#  'ещё': 264,
#  'минут': 265,
#  'про': 266,
#  '°': 267,
#  'пока': 268,
#  '000': 269,
#  'дней': 270,
#  'части': 271,
#  'нам': 272,
#  'такой': 273,
#  'марта': 274,
#  'именно': 275,
#  'дома': 276,
#  'сделать': 277,
#  '2009': 278,
#  'М': 279,
#  'Что': 280,
#  'http': 281,
#  'апреля': 282,
#  'июня': 283,
#  'своих': 284,
#  '“': 285,
#  'лишь': 286,
#  '26': 287,
#  'деятельности': 288,
#  'против': 289,
#  'организации': 290,
#  'Москве': 291,
#  'Новости': 292,
#  'да': 293,
#  'сайта': 294,
#  'декабря': 295,
#  'качестве': 296,
#  'января': 297,
#  'связи': 298,
#  'игры': 299,
#  'всем': 300,
#  'например': 301,
#  'Вам': 302,
#  '2008': 303,
#  '28': 304,
#  'над': 305,
#  'перед': 306,
#  'of': 307,
#  '27': 308,
#  'вопрос': 309,
#  'своего': 310,
#  'район': 311,
#  'образом': 312,
#  'лучше': 313,
#  'одной': 314,
#  'Украины': 315,
#  'ноября': 316,
#  'октября': 317,
#  'стал': 318,
#  'собой': 319,
#  'возможность': 320,
#  'июля': 321,
#  '40': 322,
#  'сентября': 323,
#  'сайт': 324,
#  'сегодня': 325,
#  'За': 326,
#  'февраля': 327,
#  'этих': 328,
#  'назад': 329,
#  '29': 330,
#  'мира': 331,
#  'августа': 332,
#  'жизнь': 333,
#  '$': 334,
#  'необходимо': 335,
#  'ничего': 336,
#  'около': 337,
#  '”': 338,
#  'Однако': 339,
#  'должны': 340,
#  'которого': 341,
#  'управления': 342,
#  'дня': 343,
#  'цены': 344,
#  'ул': 345,
#  'помощью': 346,
#  'Российской': 347,
#  'двух': 348,
#  'одного': 349,
#  'статьи': 350,
#  'поэтому': 351,
#  'вместе': 352,
#  'стоит': 353,
#  'цена': 354,
#  'стороны': 355,
#  '́': 356,
#  'тут': 357,
#  'развития': 358,
#  'Да': 359,
#  'потому': 360,
#  'Главная': 361,
#  'люди': 362,
#  'Купить': 363,
#  'такие': 364,
#  'хорошо': 365,
#  'The': 366,
#  'информации': 367,
#  'хотя': 368,
#  'территории': 369,
#  'тех': 370,
#  'работу': 371,
#  'весь': 372,
#  'эту': 373,
#  '©': 374,
#  'часов': 375,
#  'чего': 376,
#  'потом': 377,
#  'теперь': 378,
#  'три': 379,
#  'первый': 380,
#  'должен': 381,
#  'количество': 382,
#  'районе': 383,
#  'либо': 384,
#  'рублей': 385,
#  'Федерации': 386,
#  'вообще': 387,
#  'скачать': 388,
#  'числе': 389,
#  'момент': 390,
#  'Александр': 391,
#  '2007': 392,
#  '09': 393,
#  'из-за': 394,
#  'тогда': 395,
#  'найти': 396,
#  'права': 397,
#  'ней': 398,
#  'сразу': 399,
#  'таких': 400,
#  'виде': 401,
#  'менее': 402,
#  'находится': 403,
#  'течение': 404,
#  'каждый': 405,
#  'Вот': 406,
#  'страны': 407,
#  '31': 408,
#  'город': 409,
#  'делать': 410,
#  'другой': 411,
#  'дом': 412,
#  'Она': 413,
#  'среди': 414,
#  'СССР': 415,
#  'Скачать': 416,
#  'группы': 417,
#  'д': 418,
#  'Они': 419,
#  'данных': 420,
#  'истории': 421,
#  'тот': 422,
#  'новый': 423,
#  'почти': 424,
#  '<': 425,
#  'городе': 426,
#  'ООО': 427,
#  'Вас': 428,
#  'вопросы': 429,
#  'такое': 430,
#  'товара': 431,
#  'внимание': 432,
#  'сам': 433,
#  'этим': 434,
#  'дело': 435,
#  'г.': 436,
#  'воды': 437,
#  'войны': 438,
#  'полностью': 439,
#  'которое': 440,
#  'ним': 441,
#  'Категория': 442,
#  'достаточно': 443,
#  'the': 444,
#  'района': 445,
#  'работе': 446,
#  'часто': 447,
#  'N': 448,
#  'использовать': 449,
#  'стали': 450,
#  '@': 451,
#  'Ну': 452,
#  'период': 453,
#  '01': 454,
#  'работа': 455,
#  'средств': 456,
#  'Когда': 457,
#  'Кроме': 458,
#  '08': 459,
#  'образования': 460,
#  'являются': 461,
#  'котором': 462,
#  'новых': 463,
#  'следует': 464,
#  'нравится': 465,
#  'своим': 466,
#  'Также': 467,
#  'новые': 468,
#  'позволяет': 469,
#  'программы': 470,
#  'информацию': 471,
#  '2006': 472,
#  'ведь': 473,
#  'система': 474,
#  'информация': 475,
#  'участие': 476,
#  'смотреть': 477,
#  'книги': 478,
#  'быстро': 479,
#  'конечно': 480,
#  '·': 481,
#  '38': 482,
#  'грн': 483,
#  'отзывы': 484,
#  'ей': 485,
#  'второй': 486,
#  'название': 487,
#  'самых': 488,
#  'работ': 489,
#  'заказ': 490,
#  'начала': 491,
#  'годы': 492,
#  'слова': 493,
#  'Добавить': 494,
#  'тебя': 495,
#  'получить': 496,
#  'решение': 497,
#  'состав': 498,
#  'всей': 499,
#  'мир': 500,
#  'товаров': 501,
#  'производства': 502,
#  'порно': 503,
#  'результате': 504,
#  'затем': 505,
#  'различных': 506,
#  'данные': 507,
#  'составляет': 508,
#  'большой': 509,
#  'материалы': 510,
#  'сказал': 511,
#  'любой': 512,
#  'мире': 513,
#  'места': 514,
#  'те': 515,
#  'деньги': 516,
#  'типа': 517,
#  'месте': 518,
#  '35': 519,
#  'Поэтому': 520,
#  'компания': 521,
#  'право': 522,
#  'новости': 523,
#  'эта': 524,
#  'условиях': 525,
#  'Сергей': 526,
#  'одна': 527,
#  'имени': 528,
#  'века': 529,
#  'нашей': 530,
#  'нашем': 531,
#  'власти': 532,
#  'услуги': 533,
#  'выше': 534,
#  'Об': 535,
#  '07': 536,
#  'однако': 537,
#  'совсем': 538,
#  'тому': 539,
#  'материалов': 540,
#  'две': 541,
#  'что-то': 542,
#  'таким': 543,
#  'безопасности': 544,
#  'наиболее': 545,
#  'средства': 546,
#  'сети': 547,
#  'основе': 548,
#  'Нет': 549,
#  'свое': 550,
#  'наличии': 551,
#  'соответствии': 552,
#  'Владимир': 553,
#  'модели': 554,
#  '60': 555,
#  '~': 556,
#  'Есть': 557,
#  '02': 558,
#  '45': 559,
#  'тысяч': 560,
#  'работает': 561,
#  'кг': 562,
#  'помощи': 563,
#  'Автор': 564,
#  'возможно': 565,
#  'показать': 566,
#  '05': 567,
#  'сказать': 568,
#  'должна': 569,
#  'конце': 570,
#  'цене': 571,
#  'услуг': 572,
#  'серии': 573,
#  'Украине': 574,
#  'Чтобы': 575,
#  '32': 576,
#  'особенно': 577,
#  'вид': 578,
#  'имя': 579,
#  'регистрации': 580,
#  '....': 581,
#  'стала': 582,
#  'Сегодня': 583,
#  'обл': 584,
#  'друг': 585,
#  'Н': 586,
#  'разных': 587,
#  '2000': 588,
#  'товары': 589,
#  'Фото': 590,
#  'ответ': 591,
#  'проблемы': 592,
#  'Его': 593,
#  'имеют': 594,
#  'многие': 595,
#  '03': 596,
#  'Из': 597,
#  'фильм': 598,
#  'почему': 599,
#  'которую': 600,
#  '06': 601,
#  'одним': 602,
#  'населения': 603,
#  'Во': 604,
#  'I': 605,
#  'действия': 606,
#  'использования': 607,
#  'п': 608,
#  '200': 609,
#  'деревня': 610,
#  '500': 611,
#  'оно': 612,
#  'наших': 613,
#  'шт': 614,
#  'решения': 615,
#  'такого': 616,
#  'говорит': 617,
#  '--': 618,
#  'работать': 619,
#  'ребенка': 620,
#  '04': 621,
#  'самом': 622,
#  'язык': 623,
#  'возможности': 624,
#  'and': 625,
#  'Украина': 626,
#  'практически': 627,
#  'отзыв': 628,
#  'счет': 629,
#  'нового': 630,
#  'тебе': 631,
#  'никогда': 632,
#  'своими': 633,
#  'лица': 634,
#  'Доставка': 635,
#  'Тип': 636,
#  'центр': 637,
#  'качества': 638,
#  'этому': 639,
#  'мой': 640,
#  'получил': 641,
#  'Цена': 642,
#  'характеристики': 643,
#  'могу': 644,
#  'далее': 645,
#  'II': 646,
#  'легко': 647,
#  'Москвы': 648,
#  'нашего': 649,
#  '80': 650,
#  'сезон': 651,
#  'Подробнее': 652,
#  'рядом': 653,
#  'многих': 654,
#  '2005': 655,
#  'нее': 656,
#  'немного': 657,
#  'проекта': 658,
#  'стало': 659,
#  'первой': 660,
#  'Здесь': 661,
#  'Спасибо': 662,
#  'продукции': 663,
#  'одно': 664,
#  'рамках': 665,
#  'стоимость': 666,
#  'рождения': 667,
#  'уровень': 668,
#  'Мне': 669,
#  'обязательно': 670,
#  's': 671,
#  'оборудование': 672,
#  '36': 673,
#  'Республики': 674,
#  'цвета': 675,
#  'C': 676,
#  'р': 677,
#  'категории': 678,
#  'Только': 679,
#  'Очень': 680,
#  'знаю': 681,
#  '33': 682,
#  'интернет': 683,
#  'происходит': 684,
#  'серия': 685,
#  'уровня': 686,
#  'какой': 687,
#  'начале': 688,
#  'культуры': 689,
#  'поскольку': 690,
#  'кроме': 691,
#  'ст': 692,
#  'некоторые': 693,
#  'роль': 694,
#  'всю': 695,
#  'месяц': 696,
#  'село': 697,
#  'ч': 698,
#  'труда': 699,
#  'смерти': 700,
#  'должно': 701,
#  'телефон': 702,
#  'действительно': 703,
#  'список': 704,
#  'ранее': 705,
#  'благодаря': 706,
#  'ну': 707,
#  'Windows': 708,
#  '’': 709,
#  'Этот': 710,
#  'стать': 711,
#  '2004': 712,
#  'ниже': 713,
#  'которым': 714,
#  'нельзя': 715,
#  'отношения': 716,
#  'сами': 717,
#  'одном': 718,
#  'снова': 719,
#  'От': 720,
#  'обычно': 721,
#  'месяцев': 722,
#  'первого': 723,
#  'наш': 724,
#  'a': 725,
#  'перенаправление': 726,
#  'сообщения': 727,
#  'самое': 728,
#  'пути': 729,
#  'пор': 730,
#  'защиты': 731,
#  'б': 732,
#  'раза': 733,
#  'магазине': 734,
#  'данным': 735,
#  'описание': 736,
#  'меньше': 737,
#  '34': 738,
#  'самый': 739,
#  'выбор': 740,
#  'составе': 741,
#  'цвет': 742,
#  'значит': 743,
#  'Андрей': 744,
#  '↓': 745,
#  'номер': 746,
#  'размер': 747,
#  'данной': 748,
#  'службы': 749,
#  'самые': 750,
#  'устройства': 751,
#  '55': 752,
#  'деле': 753,
#  'каждого': 754,
#  'магазин': 755,
#  'постоянно': 756,
#  '48': 757,
#  'сколько': 758,
#  'интернет-магазине': 759,
#  'наши': 760,
#  'выбрать': 761,
#  'такая': 762,
#  'писал': 763,
#  'самого': 764,
#  'to': 765,
#  'нем': 766,
#  'прав': 767,
#  'руки': 768,
#  'питания': 769,
#  'изменения': 770,
#  'представляет': 771,
#  'данный': 772,
#  'компанией': 773,
#  'очередь': 774,
#  'лиц': 775,
#  'движения': 776,
#  'посмотреть': 777,
#  'сможете': 778,
#  'совершенно': 779,
#  'Сейчас': 780,
#  'уж': 781,
#  'формы': 782,
#  'условия': 783,
#  'in': 784,
#  'тему': 785,
#  'никто': 786,
#  'дела': 787,
#  'давно': 788,
#  'компаний': 789,
#  'проект': 790,
#  'Просмотров': 791,
#  'модель': 792,
#  'развитие': 793,
#  'процесс': 794,
#  'качество': 795,
#  'создания': 796,
#  'помощь': 797,
#  'адрес': 798,
#  'Каталог': 799,
#  'самым': 800,
#  'точно': 801,
#  'довольно': 802,
#  'Размер': 803,
#  'стране': 804,
#  'настоящее': 805,
#  '42': 806,
#  'двери': 807,
#  'вполне': 808,
#  'степени': 809,
#  'млн': 810,
#  'некоторых': 811,
#  'самой': 812,
#  'мере': 813,
#  'хочу': 814,
#  '2003': 815,
#  'идет': 816,
#  'новой': 817,
#  'срок': 818,
#  'товар': 819,
#  'школы': 820,
#  '37': 821,
#  'П': 822,
#  'становится': 823,
#  'стран': 824,
#  'женщин': 825,
#  'x': 826,
#  'объявления': 827,
#  'слишком': 828,
#  'вариант': 829,
#  'узнать': 830,
#  'стихи': 831,
#  '44': 832,
#  'др': 833,
#  'нескольких': 834,
#  'корзину': 835,
#  'Новый': 836,
#  'книгу': 837,
#  'одну': 838,
#  'данного': 839,
#  'комментарии': 840,
#  'повышения': 841,
#  'проблем': 842,
#  '300': 843,
#  'тыс.': 844,
#  'частности': 845,
#  '{': 846,
#  '70': 847,
#  'вакансии': 848,
#  'теме': 849,
#  'Ваш': 850,
#  'Теперь': 851,
#  'куда': 852,
#  'ситуации': 853,
#  'техника': 854,
#  'иногда': 855,
#  'отношение': 856,
#  'деятельность': 857,
#  'дальше': 858,
#  'словам': 859,
#  'проведения': 860,
#  'памяти': 861,
#  'До': 862,
#  '39': 863,
#  'сильно': 864,
#  'автор': 865,
#  'уровне': 866,
#  'множество': 867,
#  'спасибо': 868,
#  'число': 869,
#  'Можно': 870,
#  'зависимости': 871,
#  'техники': 872,
#  'технологии': 873,
#  'форме': 874,
#  'Г': 875,
#  'ваш': 876,
#  'государства': 877,
#  'месяца': 878,
#  'участников': 879,
#  'Ты': 880,
#  'Киев': 881,
#  'программа': 882,
#  'точки': 883,
#  'воздуха': 884,
#  'Эта': 885,
#  'транспортной': 886,
#  'группа': 887,
#  'машины': 888,
#  'правило': 889,
#  'статье': 890,
#  'Например': 891,
#  'последние': 892,
#  'xD0': 893,
#  '41': 894,
#  'примерно': 895,
#  'пожалуйста': 896,
#  'правильно': 897,
#  'Еще': 898,
#  'языка': 899,
#  'написал': 900,
#  'согласно': 901,
#  'систем': 902,
#  'л': 903,
#  'ходе': 904,
#  '46': 905,
#  'ремонт': 906,
#  'какие': 907,
#  'силы': 908,
#  'рынке': 909,
#  'Алексей': 910,
#  'иметь': 911,
#  '2001': 912,
#  'денег': 913,
#  'версия': 914,
#  'общества': 915,
#  'оборудования': 916,
#  'значение': 917,
#  'хоть': 918,
#  'своем': 919,
#  '43': 920,
#  'ними': 921,
#  'реализации': 922,
#  'состоянии': 923,
#  'другими': 924,
#  'кого': 925,
#  '2002': 926,
#  'Описание': 927,
#  'Код': 928,
#  'центра': 929,
#  'получения': 930,
#  'ряд': 931,
#  'Дата': 932,
#  'заявил': 933,
#  'статья': 934,
#  'кажется': 935,
#  'A': 936,
#  'опыт': 937,
#  'Р': 938,
#  'прямо': 939,
#  'Другие': 940,
#  'улица': 941,
#  'мог': 942,
#  'суд': 943,
#  'исследования': 944,
#  'предложения': 945,
#  'команды': 946,
#  '90': 947,
#  'органов': 948,
#  'центре': 949,
#  'неделю': 950,
#  'станет': 951,
#  '800': 952,
#  'авто': 953,
#  'история': 954,
#  'сфере': 955,
#  'той': 956,
#  'документов': 957,
#  'То': 958,
#  'мало': 959,
#  'тела': 960,
#  'т.д.': 961,
#  'вокруг': 962,
#  'записи': 963,
#  'видов': 964,
#  'отношении': 965,
#  'дети': 966,
#  'другим': 967,
#  'думаю': 968,
#  'семьи': 969,
#  'Сообщение': 970,
#  'целью': 971,
#  'глаза': 972,
#  'линии': 973,
#  'Видео': 974,
#  'конца': 975,
#  'удалось': 976,
#  '52': 977,
#  'первую': 978,
#  'поможет': 979,
#  'доме': 980,
#  'Цвет': 981,
#  'предприятия': 982,
#  'Б': 983,
#  'Русский': 984,
#  'годах': 985,
#  'Европы': 986,
#  'ко': 987,
#  'класс': 988,
#  'Читать': 989,
#  'зрения': 990,
#  'впервые': 991,
#  'равно': 992,
#  'Таким': 993,
#  'Дмитрий': 994,
#  'недели': 995,
#  'фотографии': 996,
#  'материал': 997,
#  'внутри': 998,
#  'силу': 999,
#  ...}

# %%
def index_tokens(tokens_string):
    return([word_to_idx.get(token, unk_idx) for token in tokens_string])

def fill_with_pads(tokens, pad_idx=0):
    max_len = 0
    for tokens_string in tokens:
        max_len = max(max_len, len(tokens_string))
    for tokens_string in tokens:
        for i in range(len(tokens_string), max_len):
            tokens_string.append(pad_idx)
    return tokens

def as_matrix(tokens):
    tokens = deepcopy(tokens)
    for j, s in enumerate(tokens):
        tokens[j] = index_tokens(s)
    tokens = fill_with_pads(tokens, pad_idx=pad_idx)
    return tokens

def vectorize_text(tokens):
    text_vector = np.zeros(300)
    c = 0
    for token in tokens:
        if idx_to_word[token] in ru_emb.key_to_index.keys():
            text_vector += ru_emb.get_vector(idx_to_word[token])
            c += 1
    return text_vector / 1

def batch_generator(tokens, labels, batch_size=16):
    for i in range(0, len(tokens), batch_size):
        batch_tokens = as_matrix(tokens[i: i + batch_size])
        batch_texts = np.zeros((len(batch_tokens), 300))
        for j in range(len(batch_tokens)):
            batch_texts[j] = vectorize_text(batch_tokens[j])
        batch_texts = torch.tensor(batch_texts, dtype=torch.float32)
        batch_labels = torch.tensor(labels.values[i: i + batch_size], dtype=torch.long)
        yield batch_texts, batch_labels
        
def get_train_batch(train_tkns, train_labels):
    train_tkns = as_matrix(train_tkns)
    train_texts = np.zeros((len(train_tkns), 300))
    for i in range(len(train_tkns)):
        train_texts[i] = vectorize_text(train_tkns[i])
    train_texts = torch.tensor(train_texts, dtype=torch.float32)
    train_labels = torch.tensor(train_labels.values, dtype=torch.long)
    return train_texts, train_labels       


def get_test_batch(test_tkns, test_labels):
    test_tkns = as_matrix(test_tkns)
    test_texts = np.zeros((len(test_tkns), 300))
    for i in range(len(test_tkns)):
        test_texts[i] = vectorize_text(test_tkns[i])
    test_texts = torch.tensor(test_texts, dtype=torch.float32)
    test_labels = torch.tensor(test_labels.values, dtype=torch.long)
    return test_texts, test_labels

# %%
test_batch = get_test_batch(test_tokens, y_test)
train_batch = get_train_batch(train_tokens, y_train)

# %%
test_batch
# Out:
# (tensor([[  0.2487,  -1.2180,   0.3902,  ...,   1.1659,  -0.6926,  -2.1259],
#          [  0.5040,   0.1654,  -0.3705,  ...,   1.1981,  -0.6245,  -4.6855],
#          [  0.8594, -14.6018,   3.0010,  ...,   6.1293,  -3.7954, -14.3238],
#          ...,
#          [  0.3943,  -3.4737,   0.0197,  ...,   1.2242,  -0.4231,  -5.4086],
#          [  0.3960,  -1.0643,   0.3343,  ...,   1.4477,  -0.2523,  -1.4145],
#          [  1.7983,  -5.9782,  -3.3405,  ...,   1.3952,   0.0736,  -2.8822]]),
#  tensor([0, 0, 0,  ..., 0, 0, 0]))

# %%
class LogReg(nn.Module):
    def __init__(self):
        super().__init__()
        self.linear = nn.Sequential(
            nn.Linear(300, 2)
        )
    def forward(self, batch):
        out = self.linear(batch)
        return F.softmax(out)

# %%
nnet = LogReg()
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(nnet.parameters(), lr=1e-4)

# %%
#test_tokens_as_matrix = as_matrix(test_tokens)

# %%
from IPython.display import clear_output
import matplotlib.pyplot as plt

# %%
EPOCHS = 100
BATCH_SIZE = 16
train_scores = []
test_scores = []
test_aucs = []

# %%
np.arange(0, 1)
# Out:
# array([0])

# %%
for epoch in tqdm.notebook.tqdm(range(EPOCHS)):
    nnet.train()
    batches = batch_generator(train_tokens, y_train, batch_size=BATCH_SIZE)
    for i, batch in tqdm.notebook.tqdm(enumerate(batches), total=len(train_tokens) // BATCH_SIZE):
        nnet.train()
        pred = nnet(batch[0])
        loss = criterion(pred, batch[1])
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        if i % 100 == 0:
            nnet.eval()
            train_score = criterion(nnet(batch[0]), batch[1])
            print(train_score.item())
            train_scores.append(train_score.item())
            nnet.train()
    nnet.eval()
    test_pred_prob = nnet(test_batch[0])
    test_score = criterion(test_pred_prob, test_batch[1])
    test_auc = roc_auc_score(test_batch[1], test_pred_prob.detach().numpy()[:, 1])
    test_scores.append(test_score.item())
    test_aucs.append(test_auc.item())
    nnet.train()
    clear_output(True)
    print('auc', test_auc.item())
    print('score', test_score.item())
    plt.figure(figsize=(5, 15))
    plt.subplot(3, 1, 1)
    plt.grid()
    plt.plot(np.arange(epoch + 1), test_aucs)
    plt.subplot(3, 1, 2)
    plt.grid()
    plt.scatter(np.arange(5 * (epoch + 1)) / 5, train_scores)
    plt.subplot(3, 1, 3)
    plt.plot(np.arange(epoch + 1), test_scores)
    plt.grid()
    plt.show()
# Out:
# auc 0.5212658974853069
# score 0.4750130772590637
#   0%|          | 0/476 [00:00<?, ?it/s]
# C:\Users\andre\AppData\Local\Temp\ipykernel_8972\4030111310.py:11: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return F.softmax(out)
# 0.5778409242630005
# 0.533708393573761
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "C:\Users\andre\PycharmProjects\AdClassificationProject\venv\lib\site-packages\IPython\core\interactiveshell.py", line 3378, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\andre\AppData\Local\Temp\ipykernel_8972\55566577.py", line 4, in <module>
#     for i, batch in tqdm.notebook.tqdm(enumerate(batches), total=len(train_tokens) // BATCH_SIZE):
#   File "C:\Users\andre\PycharmProjects\AdClassificationProject\venv\lib\site-packages\tqdm\notebook.py", line 259, in __iter__
#     for obj in it:
#   File "C:\Users\andre\PycharmProjects\AdClassificationProject\venv\lib\site-packages\tqdm\std.py", line 1195, in __iter__
#     for obj in iterable:
#   File "C:\Users\andre\AppData\Local\Temp\ipykernel_8972\4142700993.py", line 32, in batch_generator
#     batch_texts[j] = vectorize_text(batch_tokens[j])
#   File "C:\Users\andre\AppData\Local\Temp\ipykernel_8972\4142700993.py", line -1, in vectorize_text
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\andre\PycharmProjects\AdClassificationProject\venv\lib\site-packages\IPython\core\interactiveshell.py", line 1997, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#   File "C:\Users\andre\PycharmProjects\AdClassificationProject\venv\lib\site-packages\IPython\core\ultratb.py", line 1112, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "C:\Users\andre\PycharmProjects\AdClassificationProject\venv\lib\site-packages\IPython\core\ultratb.py", line 1006, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "C:\Users\andre\PycharmProjects\AdClassificationProject\venv\lib\site-packages\IPython\core\ultratb.py", line 859, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "C:\Users\andre\PycharmProjects\AdClassificationProject\venv\lib\site-packages\IPython\core\ultratb.py", line 812, in format_exception_as_a_whole
#     frames.append(self.format_record(r))
#   File "C:\Users\andre\PycharmProjects\AdClassificationProject\venv\lib\site-packages\IPython\core\ultratb.py", line 730, in format_record
#     result += ''.join(_format_traceback_lines(frame_info.lines, Colors, self.has_colors, lvals))
#   File "C:\Users\andre\PycharmProjects\AdClassificationProject\venv\lib\site-packages\stack_data\utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "C:\Users\andre\PycharmProjects\AdClassificationProject\venv\lib\site-packages\stack_data\core.py", line 734, in lines
#     pieces = self.included_pieces
#   File "C:\Users\andre\PycharmProjects\AdClassificationProject\venv\lib\site-packages\stack_data\utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "C:\Users\andre\PycharmProjects\AdClassificationProject\venv\lib\site-packages\stack_data\core.py", line 681, in included_pieces
#     pos = scope_pieces.index(self.executing_piece)
#   File "C:\Users\andre\PycharmProjects\AdClassificationProject\venv\lib\site-packages\stack_data\utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "C:\Users\andre\PycharmProjects\AdClassificationProject\venv\lib\site-packages\stack_data\core.py", line 660, in executing_piece
#     return only(
#   File "C:\Users\andre\PycharmProjects\AdClassificationProject\venv\lib\site-packages\executing\executing.py", line 167, in only
#     raise NotOneValueFound('Expected one value, found 0')
# executing.executing.NotOneValueFound: Expected one value, found 0

# %%
nnet(test_batch[0])[:, 0].min()
# Out:
# C:\Users\andre\AppData\Local\Temp\ipykernel_8972\4030111310.py:11: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return F.softmax(out)
# tensor(0.8481, grad_fn=<MinBackward1>)

# %%
np.arange(5 * (epoch + 1) - 1) / 5
# Out:
# array([0. , 0.2, 0.4, 0.6])

# %%
np.arange(5 * (epoch + 1) - 1)
# Out:
# array([0, 1, 2, 3])

# %%
np.random.rand()
# Out:
# 0.15947985010702936

# %%
# Out:
# 1363.7718505859375

# %%
len(word_to_idx)
# Out:
# 26238

# %%
a = pd.Series([2, 4 ,6])

# %%
a[0:2]
# Out:
# 0    2
# 1    4
# dtype: int64

# %%
test_aucs
# Out:
# [0.5069428522072333,
#  0.5086766022268636,
#  0.509926661117829,
#  0.5107370008009171,
#  0.511415424721642]

# %% [markdown]
# # Sklearn logregression

# %%
from sklearn.linear_model import LogisticRegression

X_train_wv = train_batch[0]
X_test_wv = test_batch[0]

wv_model = LogisticRegression().fit(X_train_wv, y_train)
# Out:
# C:\Users\andre\PycharmProjects\AdClassificationProject\venv\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
proba = wv_model.predict_proba(X_test_wv)[:, 1]
auc = roc_auc_score(y_test, proba)
auc
# Out:
# 0.946295427901524
